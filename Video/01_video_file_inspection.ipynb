# %% [markdown]
# # E-DAIC Video Feature Extraction and Analysis

# %% [markdown]
# This notebook implements a comprehensive pipeline for extracting and analyzing video-based features from the E-DAIC (Emotion-DAIC) dataset, primarily using OpenFace outputs.
#
# The key steps covered include:
#
# 1.  **Data Acquisition**: Streaming and extracting specific OpenFace CSV files from `tar.gz` archives hosted on the E-DAIC server.
# 2.  **Feature Engineering**:
#     *   Loading and cleaning OpenFace data (filtering by confidence and success).
#     *   Extracting various feature groups: Action Units (intensity, binary, and dynamic features like activation rates and bout durations), Head Pose (statistical, velocity, stillness, tilt), and Gaze (statistical, instability, aversion, velocity).
#     *   Calculating clinically relevant composites (e.g., Duchenne smile, negative affect).
# 3.  **Data Preprocessing**:
#     *   Aggregating features at the session level.
#     *   Merging extracted features with provided demographic and PHQ-8 (Patient Health Questionnaire-8) label data.
#     *   Handling missing values using imputation strategies (e.g., median imputation).
#     *   Normalizing features (Z-score normalization) based on the training set to prevent data leakage.
# 4.  **Clinical Interpretation**: Summarizing key features to highlight differences between depressed and non-depressed participants, providing insights into potential biomarkers for depression.

# %%
import tarfile
import urllib.request
import io

base_url = "https://dcapswoz.ict.usc.edu/wwwedaic/data/"
session_id = "300"

# Stream the tar.gz without saving it fully
url = f"{base_url}{session_id}_P.tar.gz"
response = urllib.request.urlopen(url)
buffer = io.BytesIO(response.read())

# %%
# with tarfile.open(fileobj=buffer) as tar:
#     # See what's inside first
#     print(tar.getnames())

#     # Extract only the transcript file
#     transcript = tar.extractfile(f"{session_id}_P/{session_id}_Transcript.csv")
#     content = transcript.read().decode("utf-8")

# %% [markdown]
# ['300_P', '300_P/300_AUDIO.wav', '300_P/features', '300_P/features/300_CNN_VGG.mat', '300_P/features/300_densenet201.csv', '300_P/features/300_OpenSMILE2.3.0_mfcc.csv', '300_P/features/300_BoVW_openFace_2.1.0_Pose_Gaze_AUs.csv', '300_P/features/300_vgg16.csv', '300_P/features/300_BoAW_openSMILE_2.3.0_eGeMAPS.csv', '300_P/features/300_BoAW_openSMILE_2.3.0_MFCC.csv', '300_P/features/300_OpenFace2.1.0_Pose_gaze_AUs.csv', '300_P/features/300_OpenSMILE2.3.0_egemaps.csv', '300_P/features/300_CNN_ResNet.mat', '300_P/300_Transcript.csv']

# %%
import requests
from bs4 import BeautifulSoup

labels_url = "https://dcapswoz.ict.usc.edu/wwwedaic/labels/"
response = requests.get(labels_url)
soup = BeautifulSoup(response.text, "html.parser")

# List all files
for link in soup.find_all("a"):
    href = link.get("href")
    if href and href != "../":
        print(href)
# Out:
# ?C=N;O=D
# ?C=M;O=A
# ?C=S;O=A
# ?C=D;O=A
# /wwwedaic/
# Detailed_PHQ8_Labels.csv
# detailed_lables.csv
# dev_split.csv
# test_split.csv
# train_split.csv

# %%
import pandas as pd
import io

def peek_csv(filename):
    url = f"https://dcapswoz.ict.usc.edu/wwwedaic/labels/{filename}"
    r = requests.get(url)
    df = pd.read_csv(io.StringIO(r.text))
    print(f"\n=== {filename} ===")
    print(f"Shape: {df.shape}")
    print(f"Columns: {list(df.columns)}")
    print(df.head(3))
    return df

# Also peek metadata
meta = peek_csv("../metadata_mapped.csv")
# Out:
# === ../metadata_mapped.csv ===
# Shape: (219, 7)
# Columns: ['Participant_ID', 'AVECParticipant_ID', 'Gender', 'PHQ_Binary', 'PHQ_Score', 'PCL-C (PTSD)', 'PTSD Severity']
#    Participant_ID AVECParticipant_ID  Gender  PHQ_Binary  PHQ_Score  \
# 0             302       training_001    male           0          4
# 1             303       training_002  female           0          0
# 2             304       training_003  female           0          6
#
#    PCL-C (PTSD)  PTSD Severity
# 0             0             28
# 1             0             17
# 2             0             20

# %%
import tarfile

r = requests.get("https://dcapswoz.ict.usc.edu/wwwedaic/labels2019.tar.gz")
buffer = io.BytesIO(r.content)  # only 3.2KB so fine

with tarfile.open(fileobj=buffer) as tar:
    print("Files inside labels2019.tar.gz:")
    for name in tar.getnames():
        print(" ", name)

    # Read each file inside
    for member in tar.getmembers():
        if member.name.endswith(".csv"):
            f = tar.extractfile(member)
            df = pd.read_csv(io.StringIO(f.read().decode("utf-8")))
            print(f"\n=== {member.name} ===")
            print(f"Shape: {df.shape}")
            print(f"Columns: {list(df.columns)}")
            print(df.head(3))
# Out:
# Files inside labels2019.tar.gz:
#   labels
#   labels/Detailed_PHQ8_Labels.csv
#   labels/test_split.csv
#   labels/dev_split.csv
#   labels/train_split.csv
#
# === labels/Detailed_PHQ8_Labels.csv ===
# Shape: (219, 10)
# Columns: ['Participant_ID', 'PHQ_8NoInterest', 'PHQ_8Depressed', 'PHQ_8Sleep', 'PHQ_8Tired', 'PHQ_8Appetite', 'PHQ_8Failure', 'PHQ_8Concentrating', 'PHQ_8Moving', 'PHQ_8Total']
#    Participant_ID  PHQ_8NoInterest  PHQ_8Depressed  PHQ_8Sleep  PHQ_8Tired  \
# 0             300                0               0           1           0
# 1             301                0               0           1           1
# 2             302                1               1           0           1
#
#    PHQ_8Appetite  PHQ_8Failure  PHQ_8Concentrating  PHQ_8Moving  PHQ_8Total
# 0              1             0                   0            0           2
# 1              1             0                   0            0           3
# 2              0             1                   0            0           4
#
# === labels/test_split.csv ===
# Shape: (56, 6)
# Columns: ['Participant_ID', 'Gender', 'PHQ_Binary', 'PHQ_Score', 'PCL-C (PTSD)', 'PTSD Severity']
#    Participant_ID  Gender  PHQ_Binary  PHQ_Score  PCL-C (PTSD)  PTSD Severity
# 0             600  female           0          5             0           23.0
# 1             602  female           1         13             1           67.0
# 2             604    male           1         12             0           30.0
#
# === labels/dev_split.csv ===
# Shape: (56, 6)
# Columns: ['Participant_ID', 'Gender', 'PHQ_Binary', 'PHQ_Score', 'PCL-C (PTSD)', 'PTSD Severity']
#    Participant_ID  Gender  PHQ_Binary  PHQ_Score  PCL-C (PTSD)  PTSD Severity
# 0             300    male           0          2             0             25
# 1             301    male           0          3             0             17
# 2             306  female           0          0             0             21
#
# === labels/train_split.csv ===
# Shape: (163, 6)
# Columns: ['Participant_ID', 'Gender', 'PHQ_Binary', 'PHQ_Score', 'PCL-C (PTSD)', 'PTSD Severity']
#    Participant_ID  Gender  PHQ_Binary  PHQ_Score  PCL-C (PTSD)  PTSD Severity
# 0             302    male           0          4             0             28
# 1             303  female           0          0             0             17
# 2             304  female           0          6             0             20

# %%
# %%bash
# # This only downloads enough bytes to read the tar headers — stops early
# curl -s "https://dcapswoz.ict.usc.edu/wwwedaic/data/300_P.tar.gz"
#   | tar -tzf - 2>/dev/null | head -30

# %%
FILES_TO_EXTRACT = [
    "{sid}_Transcript.csv",                              # NLP
    "features/{sid}_OpenFace2.1.0_Pose_gaze_AUs.csv",  # Video frame-level
    "features/{sid}_OpenSMILE2.3.0_egemaps.csv",        # Audio (eGeMAPS better than MFCC for affect)
    "features/{sid}_BoVW_openFace_2.1.0_Pose_Gaze_AUs.csv",  # Video aggregated
    "features/{sid}_BoAW_openSMILE_2.3.0_eGeMAPS.csv", # Audio aggregated
]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import requests
import tarfile
import io
import os
import pandas as pd

BASE_URL = "https://dcapswoz.ict.usc.edu/wwwedaic/data/"
SAVE_DIR = "/content/drive/MyDrive/edaic3.0"  # change to your path
os.makedirs(SAVE_DIR, exist_ok=True)

def download_session(session_id):
    sid = str(session_id)
    url = f"{BASE_URL}{sid}_P.tar.gz"
    out_dir = os.path.join(SAVE_DIR, sid)
    os.makedirs(out_dir, exist_ok=True)
    # if os.path.exists(out_dir) and len(os.listdir(out_dir)) > 0:
    #   print(f"[{sid}] Already extracted. Skipping download.")
    #   return


    print(f"\n[{sid}] Downloading...", end=" ")
    response = requests.get(url, stream=True)
    if response.status_code != 200:
        print(f"FAILED ({response.status_code})")
        return

    # Buffer the full tar
    chunks = []
    for chunk in response.iter_content(chunk_size=1024*1024):
        chunks.append(chunk)
    buffer = io.BytesIO(b"".join(chunks))
    print("Done. Extracting...")

    with tarfile.open(fileobj=buffer) as tar:
        for file_template in FILES_TO_EXTRACT:
            fname = file_template.format(sid=sid)
            tar_path = f"{sid}_P/{fname}"
            try:
                member = tar.getmember(tar_path)
                f = tar.extractfile(member)
                if f:
                    # Flatten into out_dir, preserve features/ subdir
                    out_path = os.path.join(out_dir, fname)
                    os.makedirs(os.path.dirname(out_path), exist_ok=True)
                    with open(out_path, "wb") as out_file:
                        out_file.write(f.read())
                    print(f"  ✓ {fname}")
            except KeyError:
                print(f"  ✗ {fname} not found")

# %%
# Out:
# 275

# %%
labels = pd.DataFrame() # Initialize as an empty DataFrame
session_ids = [] # Initialize session_ids as a list
buffer.seek(0) # Reset buffer to the beginning to read the tar file again
with tarfile.open(fileobj=buffer) as tar:
    # Read each file inside
    for member in tar.getmembers():
        # Process only the test, dev, and train split CSVs within the 'labels/' directory
        if member.name.endswith(".csv") and member.name.startswith(("labels/test", "labels/dev", "labels/train")):
            f = tar.extractfile(member)
            if f: # Ensure file object is not None
                df = pd.read_csv(io.StringIO(f.read().decode("utf-8")))
                labels = pd.concat([labels, df], ignore_index=True) # Correct way to append DataFrames
                print(f"\n=== {member.name} ===")
                print(f"Shape: {df.shape}")
                # Extend session_ids with Participant_IDs from the current dataframe
                session_ids.extend(df["Participant_ID"].tolist())
# Out:
# === labels/test_split.csv ===
# Shape: (56, 6)
#
# === labels/dev_split.csv ===
# Shape: (56, 6)
#
# === labels/train_split.csv ===
# Shape: (163, 6)

# %%
len(session_ids)
# Out:
# 275

# %%
# # Run for all sessions — load IDs from your labels CSV
# # The train_split.csv is already loaded into the 'df' variable from a previous cell.
# labels = df # Use the DataFrame 'df' which contains the train_split.csv data
# session_ids = labels["Participant_ID"].tolist()

# %%
ald_down = df["Participant_ID"].tolist()

# %%
resume_session_id = session_ids[39:]
ald_down_set = set(ald_down) # Convert to set for efficient lookup
resume_session_id = [id_val for id_val in resume_session_id if id_val not in ald_down_set]

# %%
len(resume_session_id)
# Out:
# 73

# %%
for sid in resume_session_id:
    download_session(sid)
# Out:
# [682] Downloading... Done. Extracting...
#   ✓ 682_Transcript.csv
#   ✓ features/682_OpenFace2.1.0_Pose_gaze_AUs.csv
#   ✓ features/682_OpenSMILE2.3.0_egemaps.csv
#   ✓ features/682_BoVW_openFace_2.1.0_Pose_Gaze_AUs.csv
#   ✓ features/682_BoAW_openSMILE_2.3.0_eGeMAPS.csv
#
# [683] Downloading... Done. Extracting...
#   ✓ 683_Transcript.csv
#   ✓ features/683_OpenFace2.1.0_Pose_gaze_AUs.csv
#   ✓ features/683_OpenSMILE2.3.0_egemaps.csv
#   ✓ features/683_BoVW_openFace_2.1.0_Pose_Gaze_AUs.csv
#   ✓ features/683_BoAW_openSMILE_2.3.0_eGeMAPS.csv
#
# [688] Downloading... Done. Extracting...
#   ✓ 688_Transcript.csv
#   ✓ features/688_OpenFace2.1.0_Pose_gaze_AUs.csv
#   ✓ features/688_OpenSMILE2.3.0_egemaps.csv
#   ✓ features/688_BoVW_openFace_2.1.0_Pose_Gaze_AUs.csv
#   ✓ features/688_BoAW_openSMILE_2.3.0_eGeMAPS.csv
#
# [689] Downloading... Done. Extracting...
#   ✓ 689_Transcript.csv
#   ✓ features/689_OpenFace2.1.0_Pose_gaze_AUs.csv
#   ✓ features/689_OpenSMILE2.3.0_egemaps.csv
#   ✓ features/689_BoVW_openFace_2.1.0_Pose_Gaze_AUs.csv
#   ✓ features/689_BoAW_openSMILE_2.3.0_eGeMAPS.csv
#
# [691] Downloading... Done. Extracting...
#   ✓ 691_Transcript.csv
#   ✓ features/691_OpenFace2.1.0_Pose_gaze_AUs.csv
#   ✓ features/691_OpenSMILE2.3.0_egemaps.csv
#   ✓ features/691_BoVW_openFace_2.1.0_Pose_Gaze_AUs.csv
#   ✓ features/691_BoAW_openSMILE_2.3.0_eGeMAPS.csv
#
# [693] Downloading... Done. Extracting...
#   ✓ 693_Transcript.csv
#   ✓ features/693_OpenFace2.1.0_Pose_gaze_AUs.csv
#   ✓ features/693_OpenSMILE2.3.0_egemaps.csv
#   ✓ features/693_BoVW_openFace_2.1.0_Pose_Gaze_AUs.csv
#   ✓ features/693_BoAW_openSMILE_2.3.0_eGeMAPS.csv
#
# [696] Downloading... Done. Extracting...
#   ✓ 696_Transcript.csv
#   ✓ features/696_OpenFace2.1.0_Pose_gaze_AUs.csv
#   ✓ features/696_OpenSMILE2.3.0_egemaps.csv
#   ✓ features/696_BoVW_openFace_2.1.0_Pose_Gaze_AUs.csv
#   ✓ features/696_BoAW_openSMILE_2.3.0_eGeMAPS.csv
#
# [699] Downloading... Done. Extracting...
#   ✓ 699_Transcript.csv
#   ✓ features/699_OpenFace2.1.0_Pose_gaze_AUs.csv
#   ✓ features/699_OpenSMILE2.3.0_egemaps.csv
#   ✓ features/699_BoVW_openFace_2.1.0_Pose_Gaze_AUs.csv
#   ✓ features/699_BoAW_openSMILE_2.3.0_eGeMAPS.csv
#
# [705] Downloading... Done. Extracting...
#   ✓ 705_Transcript.csv
#   ✓ features/705_OpenFace2.1.0_Pose_gaze_AUs.csv
#   ✓ features/705_OpenSMILE2.3.0_egemaps.csv
#   ✓ features/705_BoVW_openFace_2.1.0_Pose_Gaze_AUs.csv
#   ✓ features/705_BoAW_openSMILE_2.3.0_eGeMAPS.csv
#
# [708] Downloading... Done. Extracting...
#   ✓ 708_Transcript.csv
#   ✓ features/708_OpenFace2.1.0_Pose_gaze_AUs.csv
#   ✓ features/708_OpenSMILE2.3.0_egemaps.csv
#   ✓ features/708_BoVW_openFace_2.1.0_Pose_Gaze_AUs.csv
#   ✓ features/708_BoAW_openSMILE_2.3.0_eGeMAPS.csv
#
# [709] Downloading... Done. Extracting...
#   ✓ 709_Transcript.csv
#   ✓ features/709_OpenFace2.1.0_Pose_gaze_AUs.csv
#   ✓ features/709_OpenSMILE2.3.0_egemaps.csv
#   ✓ features/709_BoVW_openFace_2.1.0_Pose_Gaze_AUs.csv
#   ✓ features/709_BoAW_openSMILE_2.3.0_eGeMAPS.csv
#
# [710] Downloading... Done. Extracting...
#   ✓ 710_Transcript.csv
#   ✓ features/710_OpenFace2.1.0_Pose_gaze_AUs.csv
#   ✓ features/710_OpenSMILE2.3.0_egemaps.csv
#   ✓ features/710_BoVW_openFace_2.1.0_Pose_Gaze_AUs.csv
#   ✓ features/710_BoAW_openSMILE_2.3.0_eGeMAPS.csv
#
# [712] Downloading... Done. Extracting...
#   ✓ 712_Transcript.csv
#   ✓ features/712_OpenFace2.1.0_Pose_gaze_AUs.csv
#   ✓ features/712_OpenSMILE2.3.0_egemaps.csv
#   ✓ features/712_BoVW_openFace_2.1.0_Pose_Gaze_AUs.csv
#   ✓ features/712_BoAW_openSMILE_2.3.0_eGeMAPS.csv
#
# [715] Downloading... Done. Extracting...
#   ✓ 715_Transcript.csv
#   ✓ features/715_OpenFace2.1.0_Pose_gaze_AUs.csv
#   ✓ features/715_OpenSMILE2.3.0_egemaps.csv
#   ✓ features/715_BoVW_openFace_2.1.0_Pose_Gaze_AUs.csv
#   ✓ features/715_BoAW_openSMILE_2.3.0_eGeMAPS.csv
#
# [716] Downloading... Done. Extracting...
#   ✓ 716_Transcript.csv
#   ✓ features/716_OpenFace2.1.0_Pose_gaze_AUs.csv
#   ✓ features/716_OpenSMILE2.3.0_egemaps.csv
#   ✓ features/716_BoVW_openFace_2.1.0_Pose_Gaze_AUs.csv
#   ✓ features/716_BoAW_openSMILE_2.3.0_eGeMAPS.csv
#
# [717] Downloading... Done. Extracting...
#   ✓ 717_Transcript.csv
#   ✓ features/717_OpenFace2.1.0_Pose_gaze_AUs.csv
#   ✓ features/717_OpenSMILE2.3.0_egemaps.csv
#   ✓ features/717_BoVW_openFace_2.1.0_Pose_Gaze_AUs.csv
#   ✓ features/717_BoAW_openSMILE_2.3.0_eGeMAPS.csv
#
# [718] Downloading... Done. Extracting...
#   ✓ 718_Transcript.csv
#   ✓ features/718_OpenFace2.1.0_Pose_gaze_AUs.csv
#   ✓ features/718_OpenSMILE2.3.0_egemaps.csv
#   ✓ features/718_BoVW_openFace_2.1.0_Pose_Gaze_AUs.csv
#   ✓ features/718_BoAW_openSMILE_2.3.0_eGeMAPS.csv
#
# [300] Downloading... Done. Extracting...
#   ✓ 300_Transcript.csv
#   ✓ features/300_OpenFace2.1.0_Pose_gaze_AUs.csv
#   ✓ features/300_OpenSMILE2.3.0_egemaps.csv
#   ✓ features/300_BoVW_openFace_2.1.0_Pose_Gaze_AUs.csv
#   ✓ features/300_BoAW_openSMILE_2.3.0_eGeMAPS.csv
#
# [301] Downloading... Done. Extracting...
#   ✓ 301_Transcript.csv
#   ✓ features/301_OpenFace2.1.0_Pose_gaze_AUs.csv
#   ✓ features/301_OpenSMILE2.3.0_egemaps.csv
#   ✓ features/301_BoVW_openFace_2.1.0_Pose_Gaze_AUs.csv
#   ✓ features/301_BoAW_openSMILE_2.3.0_eGeMAPS.csv
#
# [306] Downloading... Done. Extracting...
#   ✓ 306_Transcript.csv
#   ✓ features/306_OpenFace2.1.0_Pose_gaze_AUs.csv
#   ✓ features/306_OpenSMILE2.3.0_egemaps.csv
#   ✓ features/306_BoVW_openFace_2.1.0_Pose_Gaze_AUs.csv
#   ✓ features/306_BoAW_openSMILE_2.3.0_eGeMAPS.csv
#
# [317] Downloading... Done. Extracting...
#   ✓ 317_Transcript.csv
#   ✓ features/317_OpenFace2.1.0_Pose_gaze_AUs.csv
#   ✓ features/317_OpenSMILE2.3.0_egemaps.csv
#   ✓ features/317_BoVW_openFace_2.1.0_Pose_Gaze_AUs.csv
#   ✓ features/317_BoAW_openSMILE_2.3.0_eGeMAPS.csv
#
# [320] Downloading... Done. Extracting...
#   ✓ 320_Transcript.csv
#   ✓ features/320_OpenFace2.1.0_Pose_gaze_AUs.csv
#   ✓ features/320_OpenSMILE2.3.0_egemaps.csv
#   ✓ features/320_BoVW_openFace_2.1.0_Pose_Gaze_AUs.csv
#   ✓ features/320_BoAW_openSMILE_2.3.0_eGeMAPS.csv
#
# [321] Downloading... Done. Extracting...
#   ✓ 321_Transcript.csv
#   ✓ features/321_OpenFace2.1.0_Pose_gaze_AUs.csv
#   ✓ features/321_OpenSMILE2.3.0_egemaps.csv
#   ✓ features/321_BoVW_openFace_2.1.0_Pose_Gaze_AUs.csv
#   ✓ features/321_BoAW_openSMILE_2.3.0_eGeMAPS.csv
#
# [331] Downloading... Done. Extracting...
#   ✓ 331_Transcript.csv
#   ✓ features/331_OpenFace2.1.0_Pose_gaze_AUs.csv
#   ✓ features/331_OpenSMILE2.3.0_egemaps.csv
#   ✓ features/331_BoVW_openFace_2.1.0_Pose_Gaze_AUs.csv
#   ✓ features/331_BoAW_openSMILE_2.3.0_eGeMAPS.csv
#
# [334] Downloading... Done. Extracting...
#   ✓ 334_Transcript.csv
#   ✓ features/334_OpenFace2.1.0_Pose_gaze_AUs.csv
#   ✓ features/334_OpenSMILE2.3.0_egemaps.csv
#   ✓ features/334_BoVW_openFace_2.1.0_Pose_Gaze_AUs.csv
#   ✓ features/334_BoAW_openSMILE_2.3.0_eGeMAPS.csv
#
# [336] Downloading... Done. Extracting...
#   ✓ 336_Transcript.csv
#   ✓ features/336_OpenFace2.1.0_Pose_gaze_AUs.csv
#   ✓ features/336_OpenSMILE2.3.0_egemaps.csv
#   ✓ features/336_BoVW_openFace_2.1.0_Pose_Gaze_AUs.csv
#   ✓ features/336_BoAW_openSMILE_2.3.0_eGeMAPS.csv
#
# [343] Downloading... Done. Extracting...
#   ✓ 343_Transcript.csv
#   ✓ features/343_OpenFace2.1.0_Pose_gaze_AUs.csv
#   ✓ features/343_OpenSMILE2.3.0_egemaps.csv
#   ✓ features/343_BoVW_openFace_2.1.0_Pose_Gaze_AUs.csv
#   ✓ features/343_BoAW_openSMILE_2.3.0_eGeMAPS.csv
#
# [344] Downloading... Done. Extracting...
#   ✓ 344_Transcript.csv
#   ✓ features/344_OpenFace2.1.0_Pose_gaze_AUs.csv
#   ✓ features/344_OpenSMILE2.3.0_egemaps.csv
#   ✓ features/344_BoVW_openFace_2.1.0_Pose_Gaze_AUs.csv
#   ✓ features/344_BoAW_openSMILE_2.3.0_eGeMAPS.csv
#
# [347] Downloading... Done. Extracting...
#   ✓ 347_Transcript.csv
#   ✓ features/347_OpenFace2.1.0_Pose_gaze_AUs.csv
#   ✓ features/347_OpenSMILE2.3.0_egemaps.csv
#   ✓ features/347_BoVW_openFace_2.1.0_Pose_Gaze_AUs.csv
#   ✓ features/347_BoAW_openSMILE_2.3.0_eGeMAPS.csv
#
# [350] Downloading... Done. Extracting...
#   ✓ 350_Transcript.csv
#   ✓ features/350_OpenFace2.1.0_Pose_gaze_AUs.csv
#   ✓ features/350_OpenSMILE2.3.0_egemaps.csv
#   ✓ features/350_BoVW_openFace_2.1.0_Pose_Gaze_AUs.csv
#   ✓ features/350_BoAW_openSMILE_2.3.0_eGeMAPS.csv
#
# [365] Downloading... Done. Extracting...
#   ✓ 365_Transcript.csv
#   ✓ features/365_OpenFace2.1.0_Pose_gaze_AUs.csv
#   ✓ features/365_OpenSMILE2.3.0_egemaps.csv
#   ✓ features/365_BoVW_openFace_2.1.0_Pose_Gaze_AUs.csv
#   ✓ features/365_BoAW_openSMILE_2.3.0_eGeMAPS.csv
#
# [371] Downloading... Done. Extracting...
#   ✓ 371_Transcript.csv
#   ✓ features/371_OpenFace2.1.0_Pose_gaze_AUs.csv
#   ✓ features/371_OpenSMILE2.3.0_egemaps.csv
#   ✓ features/371_BoVW_openFace_2.1.0_Pose_Gaze_AUs.csv
#   ✓ features/371_BoAW_openSMILE_2.3.0_eGeMAPS.csv
#
# [373] Downloading... Done. Extracting...
#   ✓ 373_Transcript.csv
#   ✓ features/373_OpenFace2.1.0_Pose_gaze_AUs.csv
#   ✓ features/373_OpenSMILE2.3.0_egemaps.csv
#   ✓ features/373_BoVW_openFace_2.1.0_Pose_Gaze_AUs.csv
#   ✓ features/373_BoAW_openSMILE_2.3.0_eGeMAPS.csv
#
# [374] Downloading... Done. Extracting...
#   ✓ 374_Transcript.csv
#   ✓ features/374_OpenFace2.1.0_Pose_gaze_AUs.csv
#   ✓ features/374_OpenSMILE2.3.0_egemaps.csv
#   ✓ features/374_BoVW_openFace_2.1.0_Pose_Gaze_AUs.csv
#   ✓ features/374_BoAW_openSMILE_2.3.0_eGeMAPS.csv
#
# [381] Downloading... Done. Extracting...
#   ✓ 381_Transcript.csv
#   ✓ features/381_OpenFace2.1.0_Pose_gaze_AUs.csv
#   ✓ features/381_OpenSMILE2.3.0_egemaps.csv
#   ✓ features/381_BoVW_openFace_2.1.0_Pose_Gaze_AUs.csv
#   ✓ features/381_BoAW_openSMILE_2.3.0_eGeMAPS.csv
#
# [382] Downloading... Done. Extracting...
#   ✓ 382_Transcript.csv
#   ✓ features/382_OpenFace2.1.0_Pose_gaze_AUs.csv
#   ✓ features/382_OpenSMILE2.3.0_egemaps.csv
#   ✓ features/382_BoVW_openFace_2.1.0_Pose_Gaze_AUs.csv
#   ✓ features/382_BoAW_openSMILE_2.3.0_eGeMAPS.csv
#
# [388] Downloading... Done. Extracting...
#   ✓ 388_Transcript.csv
#   ✓ features/388_OpenFace2.1.0_Pose_gaze_AUs.csv
#   ✓ features/388_OpenSMILE2.3.0_egemaps.csv
#   ✓ features/388_BoVW_openFace_2.1.0_Pose_Gaze_AUs.csv
#   ✓ features/388_BoAW_openSMILE_2.3.0_eGeMAPS.csv
#
# [393] Downloading... Done. Extracting...
#   ✓ 393_Transcript.csv
#   ✓ features/393_OpenFace2.1.0_Pose_gaze_AUs.csv
#   ✓ features/393_OpenSMILE2.3.0_egemaps.csv
#   ✓ features/393_BoVW_openFace_2.1.0_Pose_Gaze_AUs.csv
#   ✓ features/393_BoAW_openSMILE_2.3.0_eGeMAPS.csv
#
# [401] Downloading... Done. Extracting...
#   ✓ 401_Transcript.csv
#   ✓ features/401_OpenFace2.1.0_Pose_gaze_AUs.csv
#   ✓ features/401_OpenSMILE2.3.0_egemaps.csv
#   ✓ features/401_BoVW_openFace_2.1.0_Pose_Gaze_AUs.csv
#   ✓ features/401_BoAW_openSMILE_2.3.0_eGeMAPS.csv
#
# [402] Downloading... Done. Extracting...
#   ✓ 402_Transcript.csv
#   ✓ features/402_OpenFace2.1.0_Pose_gaze_AUs.csv
#   ✓ features/402_OpenSMILE2.3.0_egemaps.csv
#   ✓ features/402_BoVW_openFace_2.1.0_Pose_Gaze_AUs.csv
#   ✓ features/402_BoAW_openSMILE_2.3.0_eGeMAPS.csv
#
# [408] Downloading... Done. Extracting...
#   ✓ 408_Transcript.csv
#   ✓ features/408_OpenFace2.1.0_Pose_gaze_AUs.csv
#   ✓ features/408_OpenSMILE2.3.0_egemaps.csv
#   ✓ features/408_BoVW_openFace_2.1.0_Pose_Gaze_AUs.csv
#   ✓ features/408_BoAW_openSMILE_2.3.0_eGeMAPS.csv
#
# [412] Downloading... Done. Extracting...
#   ✓ 412_Transcript.csv
#   ✓ features/412_OpenFace2.1.0_Pose_gaze_AUs.csv
#   ✓ features/412_OpenSMILE2.3.0_egemaps.csv
#   ✓ features/412_BoVW_openFace_2.1.0_Pose_Gaze_AUs.csv
#   ✓ features/412_BoAW_openSMILE_2.3.0_eGeMAPS.csv
#
# [415] Downloading... Done. Extracting...
#   ✓ 415_Transcript.csv
#   ✓ features/415_OpenFace2.1.0_Pose_gaze_AUs.csv
#   ✓ features/415_OpenSMILE2.3.0_egemaps.csv
#   ✓ features/415_BoVW_openFace_2.1.0_Pose_Gaze_AUs.csv
#   ✓ features/415_BoAW_openSMILE_2.3.0_eGeMAPS.csv
#
# [423] Downloading... Done. Extracting...
#   ✓ 423_Transcript.csv
#   ✓ features/423_OpenFace2.1.0_Pose_gaze_AUs.csv
#   ✓ features/423_OpenSMILE2.3.0_egemaps.csv
#   ✓ features/423_BoVW_openFace_2.1.0_Pose_Gaze_AUs.csv
#   ✓ features/423_BoAW_openSMILE_2.3.0_eGeMAPS.csv
#
# [425] Downloading... Done. Extracting...
#   ✓ 425_Transcript.csv
#   ✓ features/425_OpenFace2.1.0_Pose_gaze_AUs.csv
#   ✓ features/425_OpenSMILE2.3.0_egemaps.csv
#   ✓ features/425_BoVW_openFace_2.1.0_Pose_Gaze_AUs.csv
#   ✓ features/425_BoAW_openSMILE_2.3.0_eGeMAPS.csv
#
# [431] Downloading... Done. Extracting...
#   ✓ 431_Transcript.csv
#   ✓ features/431_OpenFace2.1.0_Pose_gaze_AUs.csv
#   ✓ features/431_OpenSMILE2.3.0_egemaps.csv
#   ✓ features/431_BoVW_openFace_2.1.0_Pose_Gaze_AUs.csv
#   ✓ features/431_BoAW_openSMILE_2.3.0_eGeMAPS.csv
#
# [433] Downloading... Done. Extracting...
#   ✓ 433_Transcript.csv
#   ✓ features/433_OpenFace2.1.0_Pose_gaze_AUs.csv
#   ✓ features/433_OpenSMILE2.3.0_egemaps.csv
#   ✓ features/433_BoVW_openFace_2.1.0_Pose_Gaze_AUs.csv
#   ✓ features/433_BoAW_openSMILE_2.3.0_eGeMAPS.csv
#
# [435] Downloading... Done. Extracting...
#   ✓ 435_Transcript.csv
#   ✓ features/435_OpenFace2.1.0_Pose_gaze_AUs.csv
#   ✓ features/435_OpenSMILE2.3.0_egemaps.csv
#   ✓ features/435_BoVW_openFace_2.1.0_Pose_Gaze_AUs.csv
#   ✓ features/435_BoAW_openSMILE_2.3.0_eGeMAPS.csv
#
# [437] Downloading... Done. Extracting...
#   ✓ 437_Transcript.csv
#   ✓ features/437_OpenFace2.1.0_Pose_gaze_AUs.csv
#   ✓ features/437_OpenSMILE2.3.0_egemaps.csv
#   ✓ features/437_BoVW_openFace_2.1.0_Pose_Gaze_AUs.csv
#   ✓ features/437_BoAW_openSMILE_2.3.0_eGeMAPS.csv
#
# [441] Downloading... Done. Extracting...
#   ✓ 441_Transcript.csv
#   ✓ features/441_OpenFace2.1.0_Pose_gaze_AUs.csv
#   ✓ features/441_OpenSMILE2.3.0_egemaps.csv
#   ✓ features/441_BoVW_openFace_2.1.0_Pose_Gaze_AUs.csv
#   ✓ features/441_BoAW_openSMILE_2.3.0_eGeMAPS.csv
#
# [442] Downloading... Done. Extracting...
#   ✓ 442_Transcript.csv
#   ✓ features/442_OpenFace2.1.0_Pose_gaze_AUs.csv
#   ✓ features/442_OpenSMILE2.3.0_egemaps.csv
#   ✓ features/442_BoVW_openFace_2.1.0_Pose_Gaze_AUs.csv
#   ✓ features/442_BoAW_openSMILE_2.3.0_eGeMAPS.csv
#
# [448] Downloading... Done. Extracting...
#   ✓ 448_Transcript.csv
#   ✓ features/448_OpenFace2.1.0_Pose_gaze_AUs.csv
#   ✓ features/448_OpenSMILE2.3.0_egemaps.csv
#   ✓ features/448_BoVW_openFace_2.1.0_Pose_Gaze_AUs.csv
#   ✓ features/448_BoAW_openSMILE_2.3.0_eGeMAPS.csv
#
# [451] Downloading... Done. Extracting...
#   ✓ 451_Transcript.csv
#   ✓ features/451_OpenFace2.1.0_Pose_gaze_AUs.csv
#   ✓ features/451_OpenSMILE2.3.0_egemaps.csv
#   ✓ features/451_BoVW_openFace_2.1.0_Pose_Gaze_AUs.csv
#   ✓ features/451_BoAW_openSMILE_2.3.0_eGeMAPS.csv
#
# [454] Downloading... Done. Extracting...
#   ✓ 454_Transcript.csv
#   ✓ features/454_OpenFace2.1.0_Pose_gaze_AUs.csv
#   ✓ features/454_OpenSMILE2.3.0_egemaps.csv
#   ✓ features/454_BoVW_openFace_2.1.0_Pose_Gaze_AUs.csv
#   ✓ features/454_BoAW_openSMILE_2.3.0_eGeMAPS.csv
#
# [455] Downloading... Done. Extracting...
#   ✓ 455_Transcript.csv
#   ✓ features/455_OpenFace2.1.0_Pose_gaze_AUs.csv
#   ✓ features/455_OpenSMILE2.3.0_egemaps.csv
#   ✓ features/455_BoVW_openFace_2.1.0_Pose_Gaze_AUs.csv
#   ✓ features/455_BoAW_openSMILE_2.3.0_eGeMAPS.csv
#
# [465] Downloading... Done. Extracting...
#   ✓ 465_Transcript.csv
#   ✓ features/465_OpenFace2.1.0_Pose_gaze_AUs.csv
#   ✓ features/465_OpenSMILE2.3.0_egemaps.csv
#   ✓ features/465_BoVW_openFace_2.1.0_Pose_Gaze_AUs.csv
#   ✓ features/465_BoAW_openSMILE_2.3.0_eGeMAPS.csv
#
# [468] Downloading... Done. Extracting...
#   ✓ 468_Transcript.csv
#   ✓ features/468_OpenFace2.1.0_Pose_gaze_AUs.csv
#   ✓ features/468_OpenSMILE2.3.0_egemaps.csv
#   ✓ features/468_BoVW_openFace_2.1.0_Pose_Gaze_AUs.csv
#   ✓ features/468_BoAW_openSMILE_2.3.0_eGeMAPS.csv
#
# [473] Downloading... Done. Extracting...
#   ✓ 473_Transcript.csv
#   ✓ features/473_OpenFace2.1.0_Pose_gaze_AUs.csv
#   ✓ features/473_OpenSMILE2.3.0_egemaps.csv
#   ✓ features/473_BoVW_openFace_2.1.0_Pose_Gaze_AUs.csv
#   ✓ features/473_BoAW_openSMILE_2.3.0_eGeMAPS.csv
#
# [475] Downloading... Done. Extracting...
#   ✓ 475_Transcript.csv
#   ✓ features/475_OpenFace2.1.0_Pose_gaze_AUs.csv
#   ✓ features/475_OpenSMILE2.3.0_egemaps.csv
#   ✓ features/475_BoVW_openFace_2.1.0_Pose_Gaze_AUs.csv
#   ✓ features/475_BoAW_openSMILE_2.3.0_eGeMAPS.csv
#
# [479] Downloading... Done. Extracting...
#   ✓ 479_Transcript.csv
#   ✓ features/479_OpenFace2.1.0_Pose_gaze_AUs.csv
#   ✓ features/479_OpenSMILE2.3.0_egemaps.csv
#   ✓ features/479_BoVW_openFace_2.1.0_Pose_Gaze_AUs.csv
#   ✓ features/479_BoAW_openSMILE_2.3.0_eGeMAPS.csv
#
# [480] Downloading... Done. Extracting...
#   ✓ 480_Transcript.csv
#   ✓ features/480_OpenFace2.1.0_Pose_gaze_AUs.csv
#   ✓ features/480_OpenSMILE2.3.0_egemaps.csv
#   ✓ features/480_BoVW_openFace_2.1.0_Pose_Gaze_AUs.csv
#   ✓ features/480_BoAW_openSMILE_2.3.0_eGeMAPS.csv
#
# [484] Downloading... Done. Extracting...
#   ✓ 484_Transcript.csv
#   ✓ features/484_OpenFace2.1.0_Pose_gaze_AUs.csv
#   ✓ features/484_OpenSMILE2.3.0_egemaps.csv
#   ✓ features/484_BoVW_openFace_2.1.0_Pose_Gaze_AUs.csv
#   ✓ features/484_BoAW_openSMILE_2.3.0_eGeMAPS.csv
#
# [486] Downloading... Done. Extracting...
#   ✓ 486_Transcript.csv
#   ✓ features/486_OpenFace2.1.0_Pose_gaze_AUs.csv
#   ✓ features/486_OpenSMILE2.3.0_egemaps.csv
#   ✓ features/486_BoVW_openFace_2.1.0_Pose_Gaze_AUs.csv
#   ✓ features/486_BoAW_openSMILE_2.3.0_eGeMAPS.csv
#
# [617] Downloading... Done. Extracting...
#   ✓ 617_Transcript.csv
#   ✓ features/617_OpenFace2.1.0_Pose_gaze_AUs.csv
#   ✓ features/617_OpenSMILE2.3.0_egemaps.csv
#   ✓ features/617_BoVW_openFace_2.1.0_Pose_Gaze_AUs.csv
#   ✓ features/617_BoAW_openSMILE_2.3.0_eGeMAPS.csv
#
# [627] Downloading... Done. Extracting...
#   ✓ 627_Transcript.csv
#   ✓ features/627_OpenFace2.1.0_Pose_gaze_AUs.csv
#   ✓ features/627_OpenSMILE2.3.0_egemaps.csv
#   ✓ features/627_BoVW_openFace_2.1.0_Pose_Gaze_AUs.csv
#   ✓ features/627_BoAW_openSMILE_2.3.0_eGeMAPS.csv
#
# [632] Downloading... Done. Extracting...
#   ✓ 632_Transcript.csv
#   ✓ features/632_OpenFace2.1.0_Pose_gaze_AUs.csv
#   ✓ features/632_OpenSMILE2.3.0_egemaps.csv
#   ✓ features/632_BoVW_openFace_2.1.0_Pose_Gaze_AUs.csv
#   ✓ features/632_BoAW_openSMILE_2.3.0_eGeMAPS.csv
#
# [653] Downloading... Done. Extracting...
#   ✓ 653_Transcript.csv
#   ✓ features/653_OpenFace2.1.0_Pose_gaze_AUs.csv
#   ✓ features/653_OpenSMILE2.3.0_egemaps.csv
#   ✓ features/653_BoVW_openFace_2.1.0_Pose_Gaze_AUs.csv
#   ✓ features/653_BoAW_openSMILE_2.3.0_eGeMAPS.csv
#
# [657] Downloading... Done. Extracting...
#   ✓ 657_Transcript.csv
#   ✓ features/657_OpenFace2.1.0_Pose_gaze_AUs.csv
#   ✓ features/657_OpenSMILE2.3.0_egemaps.csv
#   ✓ features/657_BoVW_openFace_2.1.0_Pose_Gaze_AUs.csv
#   ✓ features/657_BoAW_openSMILE_2.3.0_eGeMAPS.csv
#
# [667] Downloading... Done. Extracting...
#   ✓ 667_Transcript.csv
#   ✓ features/667_OpenFace2.1.0_Pose_gaze_AUs.csv
#   ✓ features/667_OpenSMILE2.3.0_egemaps.csv
#   ✓ features/667_BoVW_openFace_2.1.0_Pose_Gaze_AUs.csv
#   ✓ features/667_BoAW_openSMILE_2.3.0_eGeMAPS.csv
#
# [670] Downloading... Done. Extracting...
#   ✓ 670_Transcript.csv
#   ✓ features/670_OpenFace2.1.0_Pose_gaze_AUs.csv
#   ✓ features/670_OpenSMILE2.3.0_egemaps.csv
#   ✓ features/670_BoVW_openFace_2.1.0_Pose_Gaze_AUs.csv
#   ✓ features/670_BoAW_openSMILE_2.3.0_eGeMAPS.csv
#
# [687] Downloading... Done. Extracting...
#   ✓ 687_Transcript.csv
#   ✓ features/687_OpenFace2.1.0_Pose_gaze_AUs.csv
#   ✓ features/687_OpenSMILE2.3.0_egemaps.csv
#   ✓ features/687_BoVW_openFace_2.1.0_Pose_Gaze_AUs.csv
#   ✓ features/687_BoAW_openSMILE_2.3.0_eGeMAPS.csv
#
# [698] Downloading... Done. Extracting...
#   ✓ 698_Transcript.csv
#   ✓ features/698_OpenFace2.1.0_Pose_gaze_AUs.csv
#   ✓ features/698_OpenSMILE2.3.0_egemaps.csv
#   ✓ features/698_BoVW_openFace_2.1.0_Pose_Gaze_AUs.csv
#   ✓ features/698_BoAW_openSMILE_2.3.0_eGeMAPS.csv
#
# [713] Downloading... Done. Extracting...
#   ✓ 713_Transcript.csv
#   ✓ features/713_OpenFace2.1.0_Pose_gaze_AUs.csv
#   ✓ features/713_OpenSMILE2.3.0_egemaps.csv
#   ✓ features/713_BoVW_openFace_2.1.0_Pose_Gaze_AUs.csv
#   ✓ features/713_BoAW_openSMILE_2.3.0_eGeMAPS.csv

# %%
import os
import requests

LABELS_URL = "https://dcapswoz.ict.usc.edu/wwwedaic/labels/"
SAVE_DIR = "/content/drive/MyDrive/edaic2.0/labels"

os.makedirs(SAVE_DIR, exist_ok=True)

LABEL_FILES = [
    "train_split.csv",
    "dev_split.csv",
    "test_split.csv",
    "Detailed_PHQ8_Labels.csv"
]

def download_label_files():
    for fname in LABEL_FILES:
        url = LABELS_URL + fname
        out_path = os.path.join(SAVE_DIR, fname)

        if os.path.exists(out_path):
            print(f"✓ Already exists: {fname}")
            continue

        r = requests.get(url)

        if r.status_code == 200:
            with open(out_path, "wb") as f:
                f.write(r.content)
            print(f"✓ Downloaded: {fname}")
        else:
            print(f"✗ Failed: {fname} | Status code: {r.status_code}")

# Run
download_label_files()
# Out:
# ✓ Downloaded: train_split.csv
# ✓ Downloaded: dev_split.csv
# ✓ Downloaded: test_split.csv
# ✓ Downloaded: Detailed_PHQ8_Labels.csv

# %%
"""
E-DAIC Video Modality Feature Extraction Pipeline
===================================================
Source file : XXX_OpenFace2.1.0_Pose_gaze_AUs.csv  (one per session)
Output      : session-level feature vectors ready for fusion model

Feature groups extracted
------------------------
1. Action Units (AU)     — 17 AUs, continuous intensity (r) + binary presence (c)
2. Head pose             — Rx, Ry, Rz  (pitch, yaw, roll in radians)
3. Gaze                  — gaze_angle_x, gaze_angle_y
4. Derived / dynamic     — smile composite, negative affect composite,
                           AU activation rates, head movement velocity,
                           gaze instability score

Each group is aggregated with: mean, std, min, max, range, median
Final output per session : ~220-dim vector  (exact count printed at runtime)

Usage
-----
    # Single session
    feats = extract_video_features("300_OpenFace2.1.0_Pose_gaze_AUs.csv", session_id=300)

    # Full dataset loop (all sessions from labels CSV)
    df = extract_all_sessions(base_url, label_df, save_path="video_features.csv")
"""

import io
import os
import requests
import tarfile
import numpy as np
import pandas as pd
from pathlib import Path
from typing import Optional

# %%
# ─────────────────────────────────────────────────────────────────────────────
# CONSTANTS
# ─────────────────────────────────────────────────────────────────────────────

BASE_URL = "https://dcapswoz.ict.usc.edu/wwwedaic/data/"

# OpenFace tracking quality threshold — discard frames below this
CONFIDENCE_THRESHOLD = 0.8

# ── Action Unit column names (continuous intensity, 0.0–5.0) ─────────────────
AU_INTENSITY_COLS = [
    "AU01_r",  # inner brow raise
    "AU02_r",  # outer brow raise
    "AU04_r",  # brow lowerer          → negative affect / concentration
    "AU05_r",  # upper lid raiser
    "AU06_r",  # cheek raiser          → Duchenne smile component
    "AU07_r",  # lid tightener
    "AU09_r",  # nose wrinkler
    "AU10_r",  # upper lip raiser
    "AU12_r",  # lip corner puller     → Duchenne smile component
    "AU14_r",  # dimpler
    "AU15_r",  # lip corner depressor  → sadness marker
    "AU17_r",  # chin raiser           → distress marker
    "AU20_r",  # lip stretcher
    "AU23_r",  # lip tightener
    "AU25_r",  # lips part
    "AU26_r",  # jaw drop
    "AU45_r",  # blink
]

# ── Action Unit column names (binary presence, 0/1) ──────────────────────────
AU_BINARY_COLS = [col.replace("_r", "_c") for col in AU_INTENSITY_COLS]

# ── Head pose columns ─────────────────────────────────────────────────────────
POSE_COLS = ["pose_Rx", "pose_Ry", "pose_Rz"]   # pitch, yaw, roll

# ── Gaze columns ──────────────────────────────────────────────────────────────
GAZE_COLS = ["gaze_angle_x", "gaze_angle_y"]

# ── Clinically meaningful AU composites ──────────────────────────────────────
# Duchenne smile = AU06 + AU12 both active at same time
SMILE_AUS       = ["AU06_r", "AU12_r"]
# Negative affect = AU04 (brow lower) + AU15 (lip corner depress) + AU17 (chin raise)
NEG_AFFECT_AUS  = ["AU04_r", "AU15_r", "AU17_r"]
# Psychomotor agitation proxy = AU01+AU02 (brow movement) + AU25 (jaw)
AGITATION_AUS   = ["AU01_r", "AU02_r", "AU25_r"]

# %%
# ─────────────────────────────────────────────────────────────────────────────
# STEP 1: LOAD & CLEAN ONE SESSION'S OPENFACE CSV
# ─────────────────────────────────────────────────────────────────────────────

def load_openface_csv(filepath_or_buffer) -> pd.DataFrame:
    """
    Load and clean one OpenFace CSV file.

    Cleaning steps:
      - Strip whitespace from column names (OpenFace adds spaces)
      - Filter frames where confidence < CONFIDENCE_THRESHOLD
      - Filter frames where success == 0 (tracking failed)
      - Reset index after filtering

    Returns cleaned DataFrame. Raises ValueError if too few valid frames remain.
    """
    df = pd.read_csv(filepath_or_buffer)

    # Strip leading/trailing spaces from column names — OpenFace quirk
    df.columns = df.columns.str.strip()

    original_len = len(df)

    # Keep only high-confidence, successful tracking frames
    if "confidence" in df.columns:
        df = df[df["confidence"] >= CONFIDENCE_THRESHOLD]
    if "success" in df.columns:
        df = df[df["success"] == 1]

    df = df.reset_index(drop=True)
    valid_len = len(df)

    print(f"    Frames: {original_len} total → {valid_len} valid "
          f"({100*valid_len/original_len:.1f}% kept)")

    if valid_len < 100:
        raise ValueError(
            f"Only {valid_len} valid frames — too few for reliable features. "
            f"Session will be skipped."
        )

    return df

# %%
# ─────────────────────────────────────────────────────────────────────────────
# STEP 2: COLUMN PRESENCE CHECK
# ─────────────────────────────────────────────────────────────────────────────

def verify_columns(df: pd.DataFrame) -> dict:
    """
    Check which expected columns are present.
    Returns a dict of flags so downstream code can skip missing groups gracefully.
    """
    present = set(df.columns)

    au_intensity_present = [c for c in AU_INTENSITY_COLS if c in present]
    au_binary_present    = [c for c in AU_BINARY_COLS    if c in present]
    pose_present         = [c for c in POSE_COLS         if c in present]
    gaze_present         = [c for c in GAZE_COLS         if c in present]

    status = {
        "au_intensity" : au_intensity_present,
        "au_binary"    : au_binary_present,
        "pose"         : pose_present,
        "gaze"         : gaze_present,
    }

    for group, cols in status.items():
        expected = {
            "au_intensity": AU_INTENSITY_COLS,
            "au_binary"   : AU_BINARY_COLS,
            "pose"        : POSE_COLS,
            "gaze"        : GAZE_COLS,
        }[group]
        missing = set(expected) - set(cols)
        if missing:
            print(f"    WARNING: {len(missing)} columns missing from {group}: {missing}")

    return status

# %%
# ─────────────────────────────────────────────────────────────────────────────
# STEP 3: STATISTICAL AGGREGATION HELPER
# ─────────────────────────────────────────────────────────────────────────────

def aggregate_stats(df: pd.DataFrame, cols: list, prefix: str) -> dict:
    """
    For each column in `cols`, compute: mean, std, min, max, range, median, p25, p75.
    Returns flat dict with keys like  "{prefix}_{col}_mean" etc.

    Why these stats?
    - mean    : average expression level across the interview
    - std     : variability / expressiveness (depression → reduced std)
    - min/max : range of expression
    - range   : max-min, direct measure of expressiveness
    - median  : robust central tendency (less affected by outliers)
    - p25/p75 : interquartile range for robust variability
    """
    features = {}
    cols_present = [c for c in cols if c in df.columns]

    for col in cols_present:
        vals = df[col].dropna().values
        if len(vals) == 0:
            for stat in ["mean","std","min","max","range","median","p25","p75"]:
                features[f"{prefix}_{col}_{stat}"] = np.nan
            continue

        features[f"{prefix}_{col}_mean"]   = float(np.mean(vals))
        features[f"{prefix}_{col}_std"]    = float(np.std(vals))
        features[f"{prefix}_{col}_min"]    = float(np.min(vals))
        features[f"{prefix}_{col}_max"]    = float(np.max(vals))
        features[f"{prefix}_{col}_range"]  = float(np.max(vals) - np.min(vals))
        features[f"{prefix}_{col}_median"] = float(np.median(vals))
        features[f"{prefix}_{col}_p25"]    = float(np.percentile(vals, 25))
        features[f"{prefix}_{col}_p75"]    = float(np.percentile(vals, 75))

    return features

# %%
# ─────────────────────────────────────────────────────────────────────────────
# STEP 4: AU-SPECIFIC FEATURES
# ─────────────────────────────────────────────────────────────────────────────

def extract_au_features(df: pd.DataFrame, au_intensity: list, au_binary: list) -> dict:
    """
    Extract Action Unit features:
      A) Statistical aggregation of all 17 AU intensities
      B) Binary presence rate (% of frames each AU is active)
      C) Clinical composites:
           - Duchenne smile rate  : % frames where AU06 AND AU12 both > 1.0
           - Negative affect score: mean of AU04 + AU15 + AU17 composite
           - Smile intensity mean : mean of AU06+AU12 when smile is active
      D) AU dynamics:
           - Activation rate      : transitions 0→1 per minute (per AU binary)
           - Mean bout duration   : average consecutive-active-frame run length
    """
    features = {}

    # ── A. Statistical aggregation ────────────────────────────────────────────
    features.update(aggregate_stats(df, au_intensity, prefix="au_int"))

    # ── B. Binary presence rate ───────────────────────────────────────────────
    for col in au_binary:
        if col in df.columns:
            features[f"au_bin_{col}_rate"] = float(df[col].mean())

    # ── C. Clinical composites ────────────────────────────────────────────────

    # Duchenne smile: AU06r > 1.0 AND AU12r > 1.0 simultaneously
    if "AU06_r" in df.columns and "AU12_r" in df.columns:
        smile_mask = (df["AU06_r"] > 1.0) & (df["AU12_r"] > 1.0)
        features["au_comp_duchenne_smile_rate"] = float(smile_mask.mean())

        # Mean smile intensity when smiling
        if smile_mask.sum() > 0:
            smile_intensity = (df.loc[smile_mask, "AU06_r"] +
                               df.loc[smile_mask, "AU12_r"]) / 2
            features["au_comp_smile_intensity_mean"] = float(smile_intensity.mean())
        else:
            features["au_comp_smile_intensity_mean"] = 0.0

    # Negative affect composite: mean(AU04, AU15, AU17) per frame → session mean
    neg_cols = [c for c in NEG_AFFECT_AUS if c in df.columns]
    if neg_cols:
        neg_composite = df[neg_cols].mean(axis=1)
        features["au_comp_neg_affect_mean"] = float(neg_composite.mean())
        features["au_comp_neg_affect_std"]  = float(neg_composite.std())

    # Agitation composite: AU01 + AU02 + AU25
    agit_cols = [c for c in AGITATION_AUS if c in df.columns]
    if agit_cols:
        agit_composite = df[agit_cols].mean(axis=1)
        features["au_comp_agitation_mean"] = float(agit_composite.mean())
        features["au_comp_agitation_std"]  = float(agit_composite.std())

    # ── D. AU dynamics (using binary columns) ─────────────────────────────────
    # Compute transitions and bout durations for key AUs only (computational cost)
    key_aus_binary = ["AU04_c", "AU06_c", "AU12_c", "AU15_c", "AU17_c"]

    # Estimate fps from timestamp column if available
    fps = 30.0  # default OpenFace fps
    if "timestamp" in df.columns and len(df) > 1:
        diffs = df["timestamp"].diff().dropna()
        median_diff = diffs.median()
        if median_diff > 0:
            fps = round(1.0 / median_diff)

    for col in key_aus_binary:
        if col not in df.columns:
            continue
        binary_seq = df[col].fillna(0).astype(int).values

        # Activation rate: number of 0→1 transitions per minute
        transitions = np.sum(np.diff(binary_seq) == 1)
        duration_min = len(binary_seq) / (fps * 60)
        features[f"au_dyn_{col}_activation_rate"] = (
            float(transitions / duration_min) if duration_min > 0 else 0.0
        )

        # Mean bout duration: average length of consecutive active runs
        bouts = []
        count = 0
        for val in binary_seq:
            if val == 1:
                count += 1
            else:
                if count > 0:
                    bouts.append(count)
                    count = 0
        if count > 0:
            bouts.append(count)

        features[f"au_dyn_{col}_mean_bout_frames"] = (
            float(np.mean(bouts)) if bouts else 0.0
        )
        features[f"au_dyn_{col}_num_bouts"] = float(len(bouts))

    return features

# %%
# ─────────────────────────────────────────────────────────────────────────────
# STEP 5: HEAD POSE FEATURES
# ─────────────────────────────────────────────────────────────────────────────

def extract_pose_features(df: pd.DataFrame, pose_cols: list) -> dict:
    """
    Extract head pose features:
      A) Statistical aggregation of Rx, Ry, Rz
      B) Head movement velocity: frame-to-frame angular change
      C) Stillness: % frames with near-zero movement (psychomotor retardation proxy)

    Clinical relevance:
      - Reduced head movement range → psychomotor retardation (PHQ_8Moving)
      - Downward head tilt (negative Rx) → avoidance / submissive posture
      - High movement variance → psychomotor agitation
    """
    features = {}

    # ── A. Statistics ─────────────────────────────────────────────────────────
    features.update(aggregate_stats(df, pose_cols, prefix="pose"))

    # ── B. Head movement velocity ─────────────────────────────────────────────
    if all(c in df.columns for c in ["pose_Rx", "pose_Ry", "pose_Rz"]):
        pose_vals = df[["pose_Rx", "pose_Ry", "pose_Rz"]].values

        # Euclidean distance between consecutive frames
        deltas = np.diff(pose_vals, axis=0)
        velocity = np.sqrt((deltas ** 2).sum(axis=1))  # rad/frame

        features["pose_velocity_mean"]   = float(np.mean(velocity))
        features["pose_velocity_std"]    = float(np.std(velocity))
        features["pose_velocity_max"]    = float(np.max(velocity))
        features["pose_velocity_p90"]    = float(np.percentile(velocity, 90))

        # Stillness: % frames with velocity < 0.01 radians
        # (proxy for psychomotor retardation — very still head)
        features["pose_stillness_rate"] = float(np.mean(velocity < 0.01))

        # Total path length (cumulative head movement over interview)
        features["pose_total_path_rad"] = float(np.sum(velocity))

    # ── C. Mean gaze direction (downward tilt proxy) ──────────────────────────
    # Negative pose_Rx = head pitched downward = avoidance posture
    if "pose_Rx" in df.columns:
        features["pose_downward_tilt_rate"] = float((df["pose_Rx"] < -0.1).mean())

    return features

# %%
# ─────────────────────────────────────────────────────────────────────────────
# STEP 6: GAZE FEATURES
# ─────────────────────────────────────────────────────────────────────────────

def extract_gaze_features(df: pd.DataFrame, gaze_cols: list) -> dict:
    """
    Extract gaze features:
      A) Statistical aggregation of gaze_angle_x, gaze_angle_y
      B) Gaze instability: std of gaze over short windows (attention proxy)
      C) Aversion rate: % frames where gaze deviates far from center (>0.3 rad)

    Clinical relevance:
      - Reduced gaze variability → reduced engagement / anhedonia
      - High gaze instability → concentration difficulty (PHQ_8Concentrating)
      - Gaze aversion → social withdrawal
    """
    features = {}

    # ── A. Statistics ─────────────────────────────────────────────────────────
    features.update(aggregate_stats(df, gaze_cols, prefix="gaze"))

    if not all(c in df.columns for c in ["gaze_angle_x", "gaze_angle_y"]):
        return features

    gx = df["gaze_angle_x"].values
    gy = df["gaze_angle_y"].values

    # ── B. Gaze instability (rolling window std) ──────────────────────────────
    # Use 90-frame (~3 second) window to capture short-term instability
    window = 90
    if len(gx) >= window:
        gaze_combined = np.sqrt(gx**2 + gy**2)  # gaze deviation magnitude
        rolling_std = pd.Series(gaze_combined).rolling(window).std().dropna().values
        features["gaze_instability_mean"] = float(np.mean(rolling_std))
        features["gaze_instability_max"]  = float(np.max(rolling_std))
    else:
        features["gaze_instability_mean"] = float(np.std(np.sqrt(gx**2 + gy**2)))
        features["gaze_instability_max"]  = np.nan

    # ── C. Gaze aversion rate ─────────────────────────────────────────────────
    # Gaze deviation from center > 0.3 rad in x OR y = looking away
    aversion_mask = (np.abs(gx) > 0.3) | (np.abs(gy) > 0.3)
    features["gaze_aversion_rate"] = float(np.mean(aversion_mask))

    # Downward gaze: gy > 0.2 rad = looking down (submissive/avoidant)
    features["gaze_downward_rate"] = float(np.mean(gy > 0.2))

    # Gaze velocity (frame-to-frame change)
    gaze_vel = np.sqrt(np.diff(gx)**2 + np.diff(gy)**2)
    features["gaze_velocity_mean"] = float(np.mean(gaze_vel))
    features["gaze_velocity_std"]  = float(np.std(gaze_vel))

    return features

# %%
# ─────────────────────────────────────────────────────────────────────────────
# STEP 7: FULL FEATURE EXTRACTION FOR ONE SESSION
# ─────────────────────────────────────────────────────────────────────────────

def extract_video_features(filepath_or_buffer, session_id: int) -> Optional[dict]:
    """
    Master function: load + clean + extract all video features for one session.

    Parameters
    ----------
    filepath_or_buffer : str, Path, or file-like object
        Path to XXX_OpenFace2.1.0_Pose_gaze_AUs.csv  OR  a BytesIO buffer
    session_id : int
        Participant ID (e.g. 300)

    Returns
    -------
    dict of {feature_name: float}  with session_id prepended,
    or None if the session fails quality checks.
    """
    print(f"\n[Session {session_id}] Extracting video features...")

    try:
        # ── Load & clean ──────────────────────────────────────────────────────
        df = load_openface_csv(filepath_or_buffer)

        # ── Verify columns ────────────────────────────────────────────────────
        status = verify_columns(df)

        # ── Extract all feature groups ────────────────────────────────────────
        all_features = {"Participant_ID": session_id}

        # Action Units
        au_feats = extract_au_features(
            df,
            au_intensity=status["au_intensity"],
            au_binary=status["au_binary"]
        )
        all_features.update(au_feats)

        # Head pose
        pose_feats = extract_pose_features(df, status["pose"])
        all_features.update(pose_feats)

        # Gaze
        gaze_feats = extract_gaze_features(df, status["gaze"])
        all_features.update(gaze_feats)

        # Total valid frames (useful for downstream quality weighting)
        all_features["video_valid_frames"] = len(df)
        all_features["video_duration_sec"] = (
            float(df["timestamp"].max()) if "timestamp" in df.columns else np.nan
        )

        print(f"    → {len(all_features) - 3} features extracted successfully")
        return all_features

    except Exception as e:
        print(f"    ERROR: {e}")
        return None

# %%
# ─────────────────────────────────────────────────────────────────────────────
# STEP 8: FULL DATASET LOOP — STREAM + EXTRACT ALL SESSIONS
# ─────────────────────────────────────────────────────────────────────────────

def stream_openface_from_tar(session_id: int) -> Optional[io.BytesIO]:
    """
    Stream a session tar.gz from the E-DAIC server and extract
    only the OpenFace CSV — without saving the full tar to disk.

    Returns BytesIO buffer of the CSV, or None on failure.
    """
    url = f"{BASE_URL}{session_id}_P.tar.gz"
    target_file = f"{session_id}_P/features/{session_id}_OpenFace2.1.0_Pose_gaze_AUs.csv"

    print(f"  Streaming {url}...", end=" ")
    try:
        response = requests.get(url, stream=True, timeout=300)
        if response.status_code != 200:
            print(f"HTTP {response.status_code}")
            return None

        chunks = []
        for chunk in response.iter_content(chunk_size=1024 * 1024):
            chunks.append(chunk)
        buffer = io.BytesIO(b"".join(chunks))
        print(f"downloaded ({sum(len(c) for c in chunks)/1e6:.0f} MB)")

        with tarfile.open(fileobj=buffer) as tar:
            try:
                member = tar.getmember(target_file)
                f = tar.extractfile(member)
                return io.BytesIO(f.read())
            except KeyError:
                print(f"    File not found in tar: {target_file}")
                return None

    except Exception as e:
        print(f"    Stream error: {e}")
        return None


def extract_all_sessions(
    label_df: pd.DataFrame,
    save_path: str = "video_features.csv",
    checkpoint_every: int = 10
) -> pd.DataFrame:
    """
    Loop over all sessions in label_df, stream each tar, extract video features.

    Parameters
    ----------
    label_df      : DataFrame with at least a 'Participant_ID' column
    save_path     : where to save the accumulated feature CSV
    checkpoint_every : save intermediate results every N sessions

    Returns
    -------
    DataFrame of shape [n_sessions x n_features]
    """
    session_ids = label_df["Participant_ID"].tolist()
    results = []
    failed = []

    print(f"Processing {len(session_ids)} sessions...\n")

    for i, sid in enumerate(session_ids):
        # Stream and extract
        csv_buffer = stream_openface_from_tar(int(sid))
        if csv_buffer is None:
            failed.append(sid)
            continue

        feats = extract_video_features(csv_buffer, session_id=int(sid))
        if feats is None:
            failed.append(sid)
            continue

        results.append(feats)

        # Checkpoint save
        if (i + 1) % checkpoint_every == 0:
            checkpoint_df = pd.DataFrame(results)
            checkpoint_df.to_csv(save_path, index=False)
            print(f"\n  [Checkpoint] Saved {len(results)} sessions to {save_path}")

    # Final save
    feature_df = pd.DataFrame(results)
    feature_df.to_csv(save_path, index=False)

    print(f"\n{'='*60}")
    print(f"Done. {len(results)} sessions extracted, {len(failed)} failed.")
    if failed:
        print(f"Failed sessions: {failed}")
    print(f"Feature matrix shape: {feature_df.shape}")
    print(f"Saved to: {save_path}")

    return feature_df

# %%
# ─────────────────────────────────────────────────────────────────────────────
# STEP 9: POST-PROCESSING — NORMALISATION & MERGE WITH LABELS
# ─────────────────────────────────────────────────────────────────────────────

def postprocess_features(
    feature_df: pd.DataFrame,
    label_df: pd.DataFrame,
    nan_strategy: str = "median"
) -> pd.DataFrame:
    """
    Post-process extracted features:
      1. Merge with labels on Participant_ID
      2. Handle NaN values (median imputation by default)
      3. Z-score normalise all feature columns (fit on train, apply to dev/test)

    Parameters
    ----------
    feature_df   : output of extract_all_sessions()
    label_df     : merged labels DataFrame with 'split' column
    nan_strategy : 'median' | 'mean' | 'zero'

    Returns
    -------
    Merged and normalised DataFrame
    """
    # ── Merge ─────────────────────────────────────────────────────────────────
    merged = label_df.merge(feature_df, on="Participant_ID", how="inner")
    print(f"Merged: {len(merged)} sessions with both features and labels")

    # Identify feature columns (exclude metadata)
    meta_cols = ["Participant_ID", "Gender", "PHQ_Binary", "PHQ_Score",
                 "PCL-C (PTSD)", "PTSD Severity", "split",
                 "PHQ_8NoInterest", "PHQ_8Depressed", "PHQ_8Sleep",
                 "PHQ_8Tired", "PHQ_8Appetite", "PHQ_8Failure",
                 "PHQ_8Concentrating", "PHQ_8Moving", "PHQ_8Total"]
    feature_cols = [c for c in merged.columns if c not in meta_cols]

    print(f"Feature columns: {len(feature_cols)}")
    print(f"NaN count before imputation: {merged[feature_cols].isna().sum().sum()}")

    # ── NaN imputation ────────────────────────────────────────────────────────
    # Compute fill values from TRAIN split only to avoid data leakage
    train_mask = merged["split"] == "train"
    for col in feature_cols:
        if merged[col].isna().any():
            if nan_strategy == "median":
                fill_val = merged.loc[train_mask, col].median()
            elif nan_strategy == "mean":
                fill_val = merged.loc[train_mask, col].mean()
            else:
                fill_val = 0.0
            merged[col] = merged[col].fillna(fill_val)

    # ── Z-score normalisation ─────────────────────────────────────────────────
    # Fit mean/std on train only
    train_mean = merged.loc[train_mask, feature_cols].mean()
    train_std  = merged.loc[train_mask, feature_cols].std().replace(0, 1)

    merged[feature_cols] = (merged[feature_cols] - train_mean) / train_std

    print(f"NaN count after imputation: {merged[feature_cols].isna().sum().sum()}")
    print(f"Final feature matrix: {merged[feature_cols].shape}")

    return merged

# %%
# ─────────────────────────────────────────────────────────────────────────────
# STEP 10: FEATURE SUMMARY & CLINICAL INTERPRETATION
# ─────────────────────────────────────────────────────────────────────────────

def summarise_features(feature_df: pd.DataFrame, label_df: pd.DataFrame):
    """
    Print a clinical summary: mean feature values for depressed vs non-depressed.
    Useful for sanity checking — depressed group should show:
      - Lower duchenne_smile_rate
      - Higher neg_affect_mean
      - Lower pose_velocity_mean (less head movement)
      - Higher gaze_aversion_rate
    """
    merged = label_df.merge(feature_df, on="Participant_ID", how="inner")
    dep   = merged[merged["PHQ_Binary"] == 1]
    nodep = merged[merged["PHQ_Binary"] == 0]

    key_features = [
        "au_comp_duchenne_smile_rate",
        "au_comp_neg_affect_mean",
        "au_comp_agitation_mean",
        "pose_velocity_mean",
        "pose_stillness_rate",
        "gaze_aversion_rate",
        "gaze_instability_mean",
    ]

    print(f"\n{'Feature':<40} {'Depressed':>12} {'Not Depressed':>14} {'Direction':>12}")
    print("-" * 80)
    for feat in key_features:
        if feat not in merged.columns:
            continue
        d_mean  = dep[feat].mean()
        nd_mean = nodep[feat].mean()
        direction = "↑ depressed" if d_mean > nd_mean else "↓ depressed"
        print(f"{feat:<40} {d_mean:>12.4f} {nd_mean:>14.4f} {direction:>12}")

# %%
# ─────────────────────────────────────────────────────────────────────────────
# MAIN — EXAMPLE RUN
# ─────────────────────────────────────────────────────────────────────────────

if __name__ == "__main__":
    import sys

    # ── Load labels ───────────────────────────────────────────────────────────
    print("Loading labels...")
    labels_base = "https://dcapswoz.ict.usc.edu/wwwedaic/labels/"

    def load_label_csv(name):
        r = requests.get(labels_base + name)
        return pd.read_csv(io.StringIO(r.text))

    train_df   = load_label_csv("train_split.csv");   train_df["split"]  = "train"
    dev_df     = load_label_csv("dev_split.csv");     dev_df["split"]    = "dev"
    test_df    = load_label_csv("test_split.csv");    test_df["split"]   = "test"
    detailed   = load_label_csv("Detailed_PHQ8_Labels.csv")

    all_labels = pd.concat([train_df, dev_df, test_df], ignore_index=True)
    all_labels = all_labels.merge(detailed, on="Participant_ID", how="left")

    print(f"Total sessions: {len(all_labels)}")

    # ── Option A: Test on a single session first ──────────────────────────────
    if "--single" in sys.argv:
        test_session = 300
        csv_buf = stream_openface_from_tar(test_session)
        if csv_buf:
            feats = extract_video_features(csv_buf, session_id=test_session)
            if feats:
                print(f"\nExtracted {len(feats)} features for session {test_session}")
                print("\nSample features:")
                for k, v in list(feats.items())[:20]:
                    print(f"  {k:<50} {v:.4f}")

    # ── Option B: Full dataset extraction ─────────────────────────────────────
    else:
        save_path = "edaic_video_features.csv"
        feature_df = extract_all_sessions(
            label_df=all_labels,
            save_path=save_path,
            checkpoint_every=10
        )

        # Post-process
        processed = postprocess_features(feature_df, all_labels)
        processed.to_csv("edaic_video_features_processed.csv", index=False)

        # Sanity check
        summarise_features(feature_df, all_labels)
# Out:
# Loading labels...
# Total sessions: 275
# Processing 275 sessions...
#
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/302_P.tar.gz... downloaded (306 MB)
#
# [Session 302] Extracting video features...
#     Frames: 22766 total → 22130 valid (97.2% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/303_P.tar.gz... downloaded (410 MB)
#
# [Session 303] Extracting video features...
#     Frames: 29565 total → 29400 valid (99.4% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/304_P.tar.gz... downloaded (354 MB)
#
# [Session 304] Extracting video features...
#     Frames: 23780 total → 23368 valid (98.3% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/305_P.tar.gz... downloaded (746 MB)
#
# [Session 305] Extracting video features...
#     Frames: 51122 total → 50947 valid (99.7% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/307_P.tar.gz... downloaded (557 MB)
#
# [Session 307] Extracting video features...
#     Frames: 37167 total → 36844 valid (99.1% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/308_P.tar.gz... downloaded (389 MB)
#
# [Session 308] Extracting video features...
#     Frames: 26031 total → 25243 valid (97.0% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/309_P.tar.gz... downloaded (314 MB)
#
# [Session 309] Extracting video features...
#     Frames: 21391 total → 21179 valid (99.0% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/310_P.tar.gz... downloaded (296 MB)
#
# [Session 310] Extracting video features...
#     Frames: 25609 total → 25268 valid (98.7% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/311_P.tar.gz... downloaded (357 MB)
#
# [Session 311] Extracting video features...
#     Frames: 23810 total → 23529 valid (98.8% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/312_P.tar.gz... downloaded (353 MB)
#
# [Session 312] Extracting video features...
#     Frames: 23945 total → 23802 valid (99.4% kept)
#     → 227 features extracted successfully
#
#   [Checkpoint] Saved 10 sessions to edaic_video_features.csv
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/313_P.tar.gz... downloaded (317 MB)
#
# [Session 313] Extracting video features...
#     Frames: 22848 total → 22640 valid (99.1% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/314_P.tar.gz... downloaded (695 MB)
#
# [Session 314] Extracting video features...
#     Frames: 46873 total → 46641 valid (99.5% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/315_P.tar.gz... downloaded (376 MB)
#
# [Session 315] Extracting video features...
#     Frames: 29561 total → 29087 valid (98.4% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/316_P.tar.gz... downloaded (388 MB)
#
# [Session 316] Extracting video features...
#     Frames: 26337 total → 26105 valid (99.1% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/318_P.tar.gz... downloaded (256 MB)
#
# [Session 318] Extracting video features...
#     Frames: 17833 total → 17679 valid (99.1% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/319_P.tar.gz... downloaded (244 MB)
#
# [Session 319] Extracting video features...
#     Frames: 20603 total → 20020 valid (97.2% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/322_P.tar.gz... downloaded (401 MB)
#
# [Session 322] Extracting video features...
#     Frames: 31412 total → 31317 valid (99.7% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/323_P.tar.gz... downloaded (358 MB)
#
# [Session 323] Extracting video features...
#     Frames: 25110 total → 24353 valid (97.0% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/324_P.tar.gz... downloaded (308 MB)
#
# [Session 324] Extracting video features...
#     Frames: 21640 total → 21385 valid (98.8% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/325_P.tar.gz... downloaded (395 MB)
#
# [Session 325] Extracting video features...
#     Frames: 26251 total → 26211 valid (99.8% kept)
#     → 227 features extracted successfully
#
#   [Checkpoint] Saved 20 sessions to edaic_video_features.csv
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/326_P.tar.gz... downloaded (255 MB)
#
# [Session 326] Extracting video features...
#     Frames: 20982 total → 20557 valid (98.0% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/327_P.tar.gz... downloaded (307 MB)
#
# [Session 327] Extracting video features...
#     Frames: 20427 total → 20276 valid (99.3% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/328_P.tar.gz... downloaded (398 MB)
#
# [Session 328] Extracting video features...
#     Frames: 31956 total → 31768 valid (99.4% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/329_P.tar.gz... downloaded (307 MB)
#
# [Session 329] Extracting video features...
#     Frames: 21192 total → 20979 valid (99.0% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/330_P.tar.gz... downloaded (320 MB)
#
# [Session 330] Extracting video features...
#     Frames: 23146 total → 22875 valid (98.8% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/332_P.tar.gz... downloaded (391 MB)
#
# [Session 332] Extracting video features...
#     Frames: 26228 total → 26121 valid (99.6% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/333_P.tar.gz... downloaded (431 MB)
#
# [Session 333] Extracting video features...
#     Frames: 29081 total → 29041 valid (99.9% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/335_P.tar.gz... downloaded (352 MB)
#
# [Session 335] Extracting video features...
#     Frames: 24902 total → 24673 valid (99.1% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/337_P.tar.gz... downloaded (839 MB)
#
# [Session 337] Extracting video features...
#     Frames: 56137 total → 56036 valid (99.8% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/338_P.tar.gz... downloaded (266 MB)
#
# [Session 338] Extracting video features...
#     Frames: 17906 total → 17323 valid (96.7% kept)
#     → 227 features extracted successfully
#
#   [Checkpoint] Saved 30 sessions to edaic_video_features.csv
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/339_P.tar.gz... downloaded (341 MB)
#
# [Session 339] Extracting video features...
#     Frames: 25892 total → 25684 valid (99.2% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/340_P.tar.gz... downloaded (260 MB)
#
# [Session 340] Extracting video features...
#     Frames: 17980 total → 17865 valid (99.4% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/341_P.tar.gz... downloaded (378 MB)
#
# [Session 341] Extracting video features...
#     Frames: 26027 total → 26024 valid (100.0% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/345_P.tar.gz... downloaded (327 MB)
#
# [Session 345] Extracting video features...
#     Frames: 23818 total → 23658 valid (99.3% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/346_P.tar.gz... downloaded (542 MB)
#
# [Session 346] Extracting video features...
#     Frames: 36656 total → 36472 valid (99.5% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/348_P.tar.gz... downloaded (324 MB)
#
# [Session 348] Extracting video features...
#     Frames: 21584 total → 21498 valid (99.6% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/349_P.tar.gz... downloaded (537 MB)
#
# [Session 349] Extracting video features...
#     Frames: 36479 total → 36075 valid (98.9% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/351_P.tar.gz... downloaded (349 MB)
#
# [Session 351] Extracting video features...
#     Frames: 23090 total → 22936 valid (99.3% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/352_P.tar.gz... downloaded (342 MB)
#
# [Session 352] Extracting video features...
#     Frames: 22808 total → 22776 valid (99.9% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/353_P.tar.gz... downloaded (349 MB)
#
# [Session 353] Extracting video features...
#     Frames: 23584 total → 23468 valid (99.5% kept)
#     → 227 features extracted successfully
#
#   [Checkpoint] Saved 40 sessions to edaic_video_features.csv
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/354_P.tar.gz... downloaded (254 MB)
#
# [Session 354] Extracting video features...
#     Frames: 17306 total → 17240 valid (99.6% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/355_P.tar.gz... downloaded (258 MB)
#
# [Session 355] Extracting video features...
#     Frames: 20242 total → 19811 valid (97.9% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/356_P.tar.gz... downloaded (431 MB)
#
# [Session 356] Extracting video features...
#     Frames: 28624 total → 28256 valid (98.7% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/357_P.tar.gz... downloaded (170 MB)
#
# [Session 357] Extracting video features...
#     Frames: 12447 total → 11999 valid (96.4% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/358_P.tar.gz... downloaded (275 MB)
#
# [Session 358] Extracting video features...
#     Frames: 19438 total → 18403 valid (94.7% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/359_P.tar.gz... downloaded (404 MB)
#
# [Session 359] Extracting video features...
#     Frames: 31012 total → 30123 valid (97.1% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/360_P.tar.gz... downloaded (193 MB)
#
# [Session 360] Extracting video features...
#     Frames: 13214 total → 12966 valid (98.1% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/361_P.tar.gz... downloaded (284 MB)
#
# [Session 361] Extracting video features...
#     Frames: 19260 total → 19031 valid (98.8% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/362_P.tar.gz... downloaded (261 MB)
#
# [Session 362] Extracting video features...
#     Frames: 17710 total → 17593 valid (99.3% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/363_P.tar.gz... downloaded (542 MB)
#
# [Session 363] Extracting video features...
#     Frames: 36814 total → 36768 valid (99.9% kept)
#     → 227 features extracted successfully
#
#   [Checkpoint] Saved 50 sessions to edaic_video_features.csv
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/364_P.tar.gz... downloaded (810 MB)
#
# [Session 364] Extracting video features...
#     Frames: 53447 total → 53423 valid (100.0% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/366_P.tar.gz... downloaded (466 MB)
#
# [Session 366] Extracting video features...
#     Frames: 39381 total → 38813 valid (98.6% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/367_P.tar.gz... downloaded (590 MB)
#
# [Session 367] Extracting video features...
#     Frames: 49112 total → 48560 valid (98.9% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/368_P.tar.gz... downloaded (542 MB)
#
# [Session 368] Extracting video features...
#     Frames: 40645 total → 39958 valid (98.3% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/369_P.tar.gz... downloaded (451 MB)
#
# [Session 369] Extracting video features...
#     Frames: 31236 total → 30393 valid (97.3% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/370_P.tar.gz... downloaded (522 MB)
#
# [Session 370] Extracting video features...
#     Frames: 36262 total → 35696 valid (98.4% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/372_P.tar.gz... downloaded (657 MB)
#
# [Session 372] Extracting video features...
#     Frames: 45416 total → 45083 valid (99.3% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/375_P.tar.gz... downloaded (255 MB)
#
# [Session 375] Extracting video features...
#     Frames: 18636 total → 17891 valid (96.0% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/376_P.tar.gz... downloaded (463 MB)
#
# [Session 376] Extracting video features...
#     Frames: 30772 total → 30570 valid (99.3% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/377_P.tar.gz... downloaded (576 MB)
#
# [Session 377] Extracting video features...
#     Frames: 39851 total → 39466 valid (99.0% kept)
#     → 227 features extracted successfully
#
#   [Checkpoint] Saved 60 sessions to edaic_video_features.csv
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/378_P.tar.gz... downloaded (385 MB)
#
# [Session 378] Extracting video features...
#     Frames: 26208 total → 26041 valid (99.4% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/379_P.tar.gz... downloaded (416 MB)
#
# [Session 379] Extracting video features...
#     Frames: 30065 total → 29338 valid (97.6% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/380_P.tar.gz... downloaded (759 MB)
#
# [Session 380] Extracting video features...
#     Frames: 58989 total → 58501 valid (99.2% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/383_P.tar.gz... downloaded (608 MB)
#
# [Session 383] Extracting video features...
#     Frames: 41074 total → 40856 valid (99.5% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/384_P.tar.gz... downloaded (468 MB)
#
# [Session 384] Extracting video features...
#     Frames: 31707 total → 31192 valid (98.4% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/385_P.tar.gz... downloaded (233 MB)
#
# [Session 385] Extracting video features...
#     Frames: 16091 total → 15781 valid (98.1% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/386_P.tar.gz... downloaded (467 MB)
#
# [Session 386] Extracting video features...
#     Frames: 31185 total → 30956 valid (99.3% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/387_P.tar.gz... downloaded (267 MB)
#
# [Session 387] Extracting video features...
#     Frames: 18084 total → 17872 valid (98.8% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/389_P.tar.gz... downloaded (404 MB)
#
# [Session 389] Extracting video features...
#     Frames: 28597 total → 27560 valid (96.4% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/390_P.tar.gz... downloaded (548 MB)
#
# [Session 390] Extracting video features...
#     Frames: 40703 total → 40329 valid (99.1% kept)
#     → 227 features extracted successfully
#
#   [Checkpoint] Saved 70 sessions to edaic_video_features.csv
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/391_P.tar.gz... downloaded (299 MB)
#
# [Session 391] Extracting video features...
#     Frames: 20405 total → 20071 valid (98.4% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/392_P.tar.gz... downloaded (283 MB)
#
# [Session 392] Extracting video features...
#     Frames: 19671 total → 19291 valid (98.1% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/395_P.tar.gz... downloaded (397 MB)
#
# [Session 395] Extracting video features...
#     Frames: 26678 total → 26181 valid (98.1% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/396_P.tar.gz... downloaded (343 MB)
#
# [Session 396] Extracting video features...
#     Frames: 23413 total → 23141 valid (98.8% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/397_P.tar.gz... downloaded (437 MB)
#
# [Session 397] Extracting video features...
#     Frames: 28599 total → 28423 valid (99.4% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/399_P.tar.gz... downloaded (308 MB)
#
# [Session 399] Extracting video features...
#     Frames: 22022 total → 21674 valid (98.4% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/400_P.tar.gz... downloaded (398 MB)
#
# [Session 400] Extracting video features...
#     Frames: 28104 total → 27927 valid (99.4% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/403_P.tar.gz... downloaded (386 MB)
#
# [Session 403] Extracting video features...
#     Frames: 25878 total → 25617 valid (99.0% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/404_P.tar.gz... downloaded (503 MB)
#
# [Session 404] Extracting video features...
#     Frames: 33920 total → 33711 valid (99.4% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/405_P.tar.gz... downloaded (718 MB)
#
# [Session 405] Extracting video features...
#     Frames: 47107 total → 46624 valid (99.0% kept)
#     → 227 features extracted successfully
#
#   [Checkpoint] Saved 80 sessions to edaic_video_features.csv
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/406_P.tar.gz... downloaded (322 MB)
#
# [Session 406] Extracting video features...
#     Frames: 21656 total → 21378 valid (98.7% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/407_P.tar.gz... downloaded (561 MB)
#
# [Session 407] Extracting video features...
#     Frames: 37575 total → 37078 valid (98.7% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/409_P.tar.gz... downloaded (461 MB)
#
# [Session 409] Extracting video features...
#     Frames: 30974 total → 30209 valid (97.5% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/410_P.tar.gz... downloaded (430 MB)
#
# [Session 410] Extracting video features...
#     Frames: 31951 total → 31840 valid (99.7% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/411_P.tar.gz... downloaded (568 MB)
#
# [Session 411] Extracting video features...
#     Frames: 41492 total → 41002 valid (98.8% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/413_P.tar.gz... downloaded (445 MB)
#
# [Session 413] Extracting video features...
#     Frames: 29906 total → 29663 valid (99.2% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/414_P.tar.gz... downloaded (434 MB)
#
# [Session 414] Extracting video features...
#     Frames: 29532 total → 29404 valid (99.6% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/416_P.tar.gz... downloaded (378 MB)
#
# [Session 416] Extracting video features...
#     Frames: 25977 total → 25295 valid (97.4% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/417_P.tar.gz... downloaded (373 MB)
#
# [Session 417] Extracting video features...
#     Frames: 26590 total → 26404 valid (99.3% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/418_P.tar.gz... downloaded (443 MB)
#
# [Session 418] Extracting video features...
#     Frames: 32680 total → 32090 valid (98.2% kept)
#     → 227 features extracted successfully
#
#   [Checkpoint] Saved 90 sessions to edaic_video_features.csv
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/419_P.tar.gz... downloaded (405 MB)
#
# [Session 419] Extracting video features...
#     Frames: 27189 total → 26921 valid (99.0% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/420_P.tar.gz... downloaded (458 MB)
#
# [Session 420] Extracting video features...
#     Frames: 31468 total → 31346 valid (99.6% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/421_P.tar.gz... downloaded (376 MB)
#
# [Session 421] Extracting video features...
#     Frames: 25110 total → 24950 valid (99.4% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/422_P.tar.gz... downloaded (590 MB)
#
# [Session 422] Extracting video features...
#     Frames: 40039 total → 39863 valid (99.6% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/424_P.tar.gz... downloaded (458 MB)
#
# [Session 424] Extracting video features...
#     Frames: 31881 total → 31611 valid (99.2% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/426_P.tar.gz... downloaded (382 MB)
#
# [Session 426] Extracting video features...
#     Frames: 25704 total → 25302 valid (98.4% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/427_P.tar.gz... downloaded (330 MB)
#
# [Session 427] Extracting video features...
#     Frames: 26154 total → 25878 valid (98.9% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/428_P.tar.gz... downloaded (305 MB)
#
# [Session 428] Extracting video features...
#     Frames: 21127 total → 20794 valid (98.4% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/429_P.tar.gz... downloaded (423 MB)
#
# [Session 429] Extracting video features...
#     Frames: 28726 total → 28593 valid (99.5% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/430_P.tar.gz... downloaded (404 MB)
#
# [Session 430] Extracting video features...
#     Frames: 27264 total → 27148 valid (99.6% kept)
#     → 227 features extracted successfully
#
#   [Checkpoint] Saved 100 sessions to edaic_video_features.csv
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/432_P.tar.gz... downloaded (354 MB)
#
# [Session 432] Extracting video features...
#     Frames: 28079 total → 27399 valid (97.6% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/434_P.tar.gz... downloaded (513 MB)
#
# [Session 434] Extracting video features...
#     Frames: 39597 total → 38841 valid (98.1% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/436_P.tar.gz... downloaded (308 MB)
#
# [Session 436] Extracting video features...
#     Frames: 20637 total → 20519 valid (99.4% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/438_P.tar.gz... downloaded (650 MB)
#
# [Session 438] Extracting video features...
#     Frames: 42901 total → 42782 valid (99.7% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/439_P.tar.gz... downloaded (544 MB)
#
# [Session 439] Extracting video features...
#     Frames: 38541 total → 38228 valid (99.2% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/440_P.tar.gz... downloaded (631 MB)
#
# [Session 440] Extracting video features...
#     Frames: 42426 total → 41621 valid (98.1% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/443_P.tar.gz... downloaded (301 MB)
#
# [Session 443] Extracting video features...
#     Frames: 21040 total → 20572 valid (97.8% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/444_P.tar.gz... downloaded (590 MB)
#
# [Session 444] Extracting video features...
#     Frames: 39317 total → 39126 valid (99.5% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/445_P.tar.gz... downloaded (259 MB)
#
# [Session 445] Extracting video features...
#     Frames: 21290 total → 21169 valid (99.4% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/446_P.tar.gz... downloaded (448 MB)
#
# [Session 446] Extracting video features...
#     Frames: 29955 total → 29759 valid (99.3% kept)
#     → 227 features extracted successfully
#
#   [Checkpoint] Saved 110 sessions to edaic_video_features.csv
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/447_P.tar.gz... downloaded (328 MB)
#
# [Session 447] Extracting video features...
#     Frames: 24610 total → 24515 valid (99.6% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/449_P.tar.gz... downloaded (471 MB)
#
# [Session 449] Extracting video features...
#     Frames: 30893 total → 30744 valid (99.5% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/450_P.tar.gz... downloaded (549 MB)
#
# [Session 450] Extracting video features...
#     Frames: 38256 total → 37857 valid (99.0% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/452_P.tar.gz... downloaded (392 MB)
#
# [Session 452] Extracting video features...
#     Frames: 26673 total → 26207 valid (98.3% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/453_P.tar.gz... downloaded (430 MB)
#
# [Session 453] Extracting video features...
#     Frames: 30969 total → 30511 valid (98.5% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/456_P.tar.gz... downloaded (398 MB)
#
# [Session 456] Extracting video features...
#     Frames: 26485 total → 26348 valid (99.5% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/457_P.tar.gz... downloaded (424 MB)
#
# [Session 457] Extracting video features...
#     Frames: 28871 total → 28754 valid (99.6% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/458_P.tar.gz... downloaded (423 MB)
#
# [Session 458] Extracting video features...
#     Frames: 28494 total → 28368 valid (99.6% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/459_P.tar.gz... downloaded (435 MB)
#
# [Session 459] Extracting video features...
#     Frames: 29254 total → 29188 valid (99.8% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/461_P.tar.gz... downloaded (430 MB)
#
# [Session 461] Extracting video features...
#     Frames: 29446 total → 29110 valid (98.9% kept)
#     → 227 features extracted successfully
#
#   [Checkpoint] Saved 120 sessions to edaic_video_features.csv
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/462_P.tar.gz... downloaded (392 MB)
#
# [Session 462] Extracting video features...
#     Frames: 28952 total → 27784 valid (96.0% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/463_P.tar.gz... downloaded (365 MB)
#
# [Session 463] Extracting video features...
#     Frames: 25039 total → 24969 valid (99.7% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/464_P.tar.gz... downloaded (445 MB)
#
# [Session 464] Extracting video features...
#     Frames: 29410 total → 29342 valid (99.8% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/466_P.tar.gz... downloaded (672 MB)
#
# [Session 466] Extracting video features...
#     Frames: 46997 total → 45583 valid (97.0% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/467_P.tar.gz... downloaded (439 MB)
#
# [Session 467] Extracting video features...
#     Frames: 30074 total → 29854 valid (99.3% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/469_P.tar.gz... downloaded (465 MB)
#
# [Session 469] Extracting video features...
#     Frames: 33799 total → 33634 valid (99.5% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/470_P.tar.gz... downloaded (364 MB)
#
# [Session 470] Extracting video features...
#     Frames: 28662 total → 28349 valid (98.9% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/471_P.tar.gz... downloaded (450 MB)
#
# [Session 471] Extracting video features...
#     Frames: 29862 total → 29811 valid (99.8% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/472_P.tar.gz... downloaded (407 MB)
#
# [Session 472] Extracting video features...
#     Frames: 27092 total → 26930 valid (99.4% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/474_P.tar.gz... downloaded (388 MB)
#
# [Session 474] Extracting video features...
#     Frames: 27822 total → 27645 valid (99.4% kept)
#     → 227 features extracted successfully
#
#   [Checkpoint] Saved 130 sessions to edaic_video_features.csv
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/476_P.tar.gz... downloaded (264 MB)
#
# [Session 476] Extracting video features...
#     Frames: 18265 total → 18153 valid (99.4% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/477_P.tar.gz... downloaded (568 MB)
#
# [Session 477] Extracting video features...
#     Frames: 37341 total → 37166 valid (99.5% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/478_P.tar.gz... downloaded (413 MB)
#
# [Session 478] Extracting video features...
#     Frames: 28087 total → 27717 valid (98.7% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/481_P.tar.gz... downloaded (497 MB)
#
# [Session 481] Extracting video features...
#     Frames: 33491 total → 33197 valid (99.1% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/482_P.tar.gz... downloaded (457 MB)
#
# [Session 482] Extracting video features...
#     Frames: 30570 total → 30471 valid (99.7% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/483_P.tar.gz... downloaded (645 MB)
#
# [Session 483] Extracting video features...
#     Frames: 47313 total → 47142 valid (99.6% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/485_P.tar.gz... downloaded (261 MB)
#
# [Session 485] Extracting video features...
#     Frames: 18082 total → 17853 valid (98.7% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/487_P.tar.gz... downloaded (453 MB)
#
# [Session 487] Extracting video features...
#     Frames: 30710 total → 30457 valid (99.2% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/488_P.tar.gz... downloaded (397 MB)
#
# [Session 488] Extracting video features...
#     Frames: 26549 total → 26187 valid (98.6% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/489_P.tar.gz... downloaded (315 MB)
#
# [Session 489] Extracting video features...
#     Frames: 21141 total → 21051 valid (99.6% kept)
#     → 227 features extracted successfully
#
#   [Checkpoint] Saved 140 sessions to edaic_video_features.csv
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/490_P.tar.gz... downloaded (273 MB)
#
# [Session 490] Extracting video features...
#     Frames: 20740 total → 20700 valid (99.8% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/491_P.tar.gz... downloaded (344 MB)
#
# [Session 491] Extracting video features...
#     Frames: 26451 total → 25681 valid (97.1% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/492_P.tar.gz... downloaded (391 MB)
#
# [Session 492] Extracting video features...
#     Frames: 27375 total → 27236 valid (99.5% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/601_P.tar.gz... downloaded (305 MB)
#
# [Session 601] Extracting video features...
#     Frames: 21157 total → 20760 valid (98.1% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/603_P.tar.gz... downloaded (671 MB)
#
# [Session 603] Extracting video features...
#     Frames: 43445 total → 43195 valid (99.4% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/608_P.tar.gz... downloaded (556 MB)
#
# [Session 608] Extracting video features...
#     Frames: 41540 total → 38338 valid (92.3% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/612_P.tar.gz... downloaded (390 MB)
#
# [Session 612] Extracting video features...
#     Frames: 27219 total → 26939 valid (99.0% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/628_P.tar.gz... downloaded (504 MB)
#
# [Session 628] Extracting video features...
#     Frames: 34946 total → 34562 valid (98.9% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/633_P.tar.gz... downloaded (807 MB)
#
# [Session 633] Extracting video features...
#     Frames: 50760 total → 50459 valid (99.4% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/641_P.tar.gz... downloaded (267 MB)
#
# [Session 641] Extracting video features...
#     Frames: 22649 total → 20999 valid (92.7% kept)
#     → 227 features extracted successfully
#
#   [Checkpoint] Saved 150 sessions to edaic_video_features.csv
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/654_P.tar.gz... downloaded (233 MB)
#
# [Session 654] Extracting video features...
#     Frames: 16692 total → 16030 valid (96.0% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/660_P.tar.gz... downloaded (360 MB)
#
# [Session 660] Extracting video features...
#     Frames: 32080 total → 26592 valid (82.9% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/662_P.tar.gz... downloaded (412 MB)
#
# [Session 662] Extracting video features...
#     Frames: 25416 total → 25354 valid (99.8% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/673_P.tar.gz... downloaded (256 MB)
#
# [Session 673] Extracting video features...
#     Frames: 18057 total → 17881 valid (99.0% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/677_P.tar.gz... downloaded (386 MB)
#
# [Session 677] Extracting video features...
#     Frames: 27012 total → 26732 valid (99.0% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/680_P.tar.gz... downloaded (693 MB)
#
# [Session 680] Extracting video features...
#     Frames: 41733 total → 41561 valid (99.6% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/684_P.tar.gz... downloaded (428 MB)
#
# [Session 684] Extracting video features...
#     Frames: 32202 total → 31901 valid (99.1% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/692_P.tar.gz... downloaded (246 MB)
#
# [Session 692] Extracting video features...
#     Frames: 16175 total → 15909 valid (98.4% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/695_P.tar.gz... downloaded (512 MB)
#
# [Session 695] Extracting video features...
#     Frames: 45204 total → 35815 valid (79.2% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/697_P.tar.gz... downloaded (478 MB)
#
# [Session 697] Extracting video features...
#     Frames: 31754 total → 31572 valid (99.4% kept)
#     → 227 features extracted successfully
#
#   [Checkpoint] Saved 160 sessions to edaic_video_features.csv
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/702_P.tar.gz... downloaded (295 MB)
#
# [Session 702] Extracting video features...
#     Frames: 21988 total → 21845 valid (99.3% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/703_P.tar.gz... downloaded (314 MB)
#
# [Session 703] Extracting video features...
#     Frames: 24391 total → 24182 valid (99.1% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/707_P.tar.gz... downloaded (406 MB)
#
# [Session 707] Extracting video features...
#     Frames: 26110 total → 25898 valid (99.2% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/300_P.tar.gz... downloaded (280 MB)
#
# [Session 300] Extracting video features...
#     Frames: 19458 total → 19378 valid (99.6% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/301_P.tar.gz... downloaded (375 MB)
#
# [Session 301] Extracting video features...
#     Frames: 24721 total → 24618 valid (99.6% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/306_P.tar.gz... downloaded (351 MB)
#
# [Session 306] Extracting video features...
#     Frames: 25744 total → 25625 valid (99.5% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/317_P.tar.gz... downloaded (362 MB)
#
# [Session 317] Extracting video features...
#     Frames: 24395 total → 24354 valid (99.8% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/320_P.tar.gz... downloaded (353 MB)
#
# [Session 320] Extracting video features...
#     Frames: 25480 total → 25145 valid (98.7% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/321_P.tar.gz... downloaded (365 MB)
#
# [Session 321] Extracting video features...
#     Frames: 24658 total → 24567 valid (99.6% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/331_P.tar.gz... downloaded (385 MB)
#
# [Session 331] Extracting video features...
#     Frames: 25524 total → 25296 valid (99.1% kept)
#     → 227 features extracted successfully
#
#   [Checkpoint] Saved 170 sessions to edaic_video_features.csv
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/334_P.tar.gz... downloaded (417 MB)
#
# [Session 334] Extracting video features...
#     Frames: 29400 total → 29104 valid (99.0% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/336_P.tar.gz... downloaded (416 MB)
#
# [Session 336] Extracting video features...
#     Frames: 28337 total → 28019 valid (98.9% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/343_P.tar.gz... downloaded (368 MB)
#
# [Session 343] Extracting video features...
#     Frames: 27819 total → 26522 valid (95.3% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/344_P.tar.gz... downloaded (436 MB)
#
# [Session 344] Extracting video features...
#     Frames: 32718 total → 32469 valid (99.2% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/347_P.tar.gz... downloaded (259 MB)
#
# [Session 347] Extracting video features...
#     Frames: 18348 total → 18005 valid (98.1% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/350_P.tar.gz... downloaded (394 MB)
#
# [Session 350] Extracting video features...
#     Frames: 26455 total → 26254 valid (99.2% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/365_P.tar.gz... downloaded (601 MB)
#
# [Session 365] Extracting video features...
#     Frames: 41585 total → 41365 valid (99.5% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/371_P.tar.gz... downloaded (383 MB)
#
# [Session 371] Extracting video features...
#     Frames: 27356 total → 26920 valid (98.4% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/373_P.tar.gz... downloaded (563 MB)
#
# [Session 373] Extracting video features...
#     Frames: 37951 total → 37632 valid (99.2% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/374_P.tar.gz... downloaded (580 MB)
#
# [Session 374] Extracting video features...
#     Frames: 38631 total → 38487 valid (99.6% kept)
#     → 227 features extracted successfully
#
#   [Checkpoint] Saved 180 sessions to edaic_video_features.csv
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/381_P.tar.gz... downloaded (476 MB)
#
# [Session 381] Extracting video features...
#     Frames: 32681 total → 32616 valid (99.8% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/382_P.tar.gz... downloaded (368 MB)
#
# [Session 382] Extracting video features...
#     Frames: 24728 total → 24690 valid (99.8% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/388_P.tar.gz... downloaded (326 MB)
#
# [Session 388] Extracting video features...
#     Frames: 24935 total → 24271 valid (97.3% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/393_P.tar.gz... downloaded (254 MB)
#
# [Session 393] Extracting video features...
#     Frames: 18904 total → 17768 valid (94.0% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/401_P.tar.gz... downloaded (416 MB)
#
# [Session 401] Extracting video features...
#     Frames: 28027 total → 27839 valid (99.3% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/402_P.tar.gz... downloaded (379 MB)
#
# [Session 402] Extracting video features...
#     Frames: 24999 total → 24621 valid (98.5% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/408_P.tar.gz... downloaded (294 MB)
#
# [Session 408] Extracting video features...
#     Frames: 21477 total → 21183 valid (98.6% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/412_P.tar.gz... downloaded (381 MB)
#
# [Session 412] Extracting video features...
#     Frames: 25709 total → 25403 valid (98.8% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/415_P.tar.gz... downloaded (329 MB)
#
# [Session 415] Extracting video features...
#     Frames: 23423 total → 23348 valid (99.7% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/423_P.tar.gz... downloaded (452 MB)
#
# [Session 423] Extracting video features...
#     Frames: 29878 total → 29757 valid (99.6% kept)
#     → 227 features extracted successfully
#
#   [Checkpoint] Saved 190 sessions to edaic_video_features.csv
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/425_P.tar.gz... downloaded (517 MB)
#
# [Session 425] Extracting video features...
#     Frames: 34644 total → 34401 valid (99.3% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/431_P.tar.gz... downloaded (291 MB)
#
# [Session 431] Extracting video features...
#     Frames: 25019 total → 24751 valid (98.9% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/433_P.tar.gz... downloaded (358 MB)
#
# [Session 433] Extracting video features...
#     Frames: 24055 total → 23783 valid (98.9% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/435_P.tar.gz... downloaded (523 MB)
#
# [Session 435] Extracting video features...
#     Frames: 35550 total → 35109 valid (98.8% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/437_P.tar.gz... downloaded (382 MB)
#
# [Session 437] Extracting video features...
#     Frames: 25487 total → 24967 valid (98.0% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/441_P.tar.gz... downloaded (392 MB)
#
# [Session 441] Extracting video features...
#     Frames: 29141 total → 28734 valid (98.6% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/442_P.tar.gz... downloaded (378 MB)
#
# [Session 442] Extracting video features...
#     Frames: 28502 total → 28381 valid (99.6% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/448_P.tar.gz... downloaded (550 MB)
#
# [Session 448] Extracting video features...
#     Frames: 36390 total → 36285 valid (99.7% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/451_P.tar.gz... downloaded (524 MB)
#
# [Session 451] Extracting video features...
#     Frames: 35654 total → 35437 valid (99.4% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/454_P.tar.gz... downloaded (352 MB)
#
# [Session 454] Extracting video features...
#     Frames: 24126 total → 24103 valid (99.9% kept)
#     → 227 features extracted successfully
#
#   [Checkpoint] Saved 200 sessions to edaic_video_features.csv
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/455_P.tar.gz... downloaded (325 MB)
#
# [Session 455] Extracting video features...
#     Frames: 22511 total → 22449 valid (99.7% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/465_P.tar.gz... downloaded (511 MB)
#
# [Session 465] Extracting video features...
#     Frames: 34905 total → 34732 valid (99.5% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/468_P.tar.gz... downloaded (410 MB)
#
# [Session 468] Extracting video features...
#     Frames: 28193 total → 28066 valid (99.5% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/473_P.tar.gz... downloaded (231 MB)
#
# [Session 473] Extracting video features...
#     Frames: 16000 total → 15873 valid (99.2% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/475_P.tar.gz... downloaded (263 MB)
#
# [Session 475] Extracting video features...
# ...
#
# [Session 632] Extracting video features...
#     Frames: 35901 total → 34785 valid (96.9% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/653_P.tar.gz... downloaded (315 MB)
#
# [Session 653] Extracting video features...
#     Frames: 19947 total → 19570 valid (98.1% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/657_P.tar.gz... downloaded (193 MB)
#
# [Session 657] Extracting video features...
#     Frames: 29005 total → 28629 valid (98.7% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/667_P.tar.gz... downloaded (377 MB)
#
# [Session 667] Extracting video features...
#     Frames: 25905 total → 24907 valid (96.1% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/670_P.tar.gz... downloaded (252 MB)
#
# [Session 670] Extracting video features...
#     Frames: 19150 total → 18908 valid (98.7% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/687_P.tar.gz... downloaded (446 MB)
#
# [Session 687] Extracting video features...
#     Frames: 33368 total → 32828 valid (98.4% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/698_P.tar.gz... downloaded (648 MB)
#
# [Session 698] Extracting video features...
#     Frames: 43364 total → 43245 valid (99.7% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/713_P.tar.gz... downloaded (360 MB)
#
# [Session 713] Extracting video features...
#     Frames: 23710 total → 23511 valid (99.2% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/600_P.tar.gz... downloaded (282 MB)
#
# [Session 600] Extracting video features...
#     Frames: 20579 total → 20573 valid (100.0% kept)
#     → 227 features extracted successfully
#
#   [Checkpoint] Saved 220 sessions to edaic_video_features.csv
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/602_P.tar.gz... downloaded (368 MB)
#
# [Session 602] Extracting video features...
#     Frames: 25550 total → 25435 valid (99.5% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/604_P.tar.gz... downloaded (273 MB)
#
# [Session 604] Extracting video features...
#     Frames: 18832 total → 18437 valid (97.9% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/605_P.tar.gz... downloaded (366 MB)
#
# [Session 605] Extracting video features...
#     Frames: 24269 total → 24091 valid (99.3% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/606_P.tar.gz... downloaded (218 MB)
#
# [Session 606] Extracting video features...
#     Frames: 15880 total → 15528 valid (97.8% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/607_P.tar.gz... downloaded (340 MB)
#
# [Session 607] Extracting video features...
#     Frames: 23773 total → 23572 valid (99.2% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/609_P.tar.gz... downloaded (535 MB)
#
# [Session 609] Extracting video features...
#     Frames: 34818 total → 34441 valid (98.9% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/615_P.tar.gz... downloaded (535 MB)
#
# [Session 615] Extracting video features...
#     Frames: 36787 total → 36257 valid (98.6% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/618_P.tar.gz... downloaded (377 MB)
#
# [Session 618] Extracting video features...
#     Frames: 26721 total → 25400 valid (95.1% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/619_P.tar.gz... downloaded (499 MB)
#
# [Session 619] Extracting video features...
#     Frames: 35059 total → 34348 valid (98.0% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/620_P.tar.gz... downloaded (525 MB)
#
# [Session 620] Extracting video features...
#     Frames: 34747 total → 32213 valid (92.7% kept)
#     → 227 features extracted successfully
#
#   [Checkpoint] Saved 230 sessions to edaic_video_features.csv
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/622_P.tar.gz... downloaded (376 MB)
#
# [Session 622] Extracting video features...
#     Frames: 24875 total → 24733 valid (99.4% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/623_P.tar.gz... downloaded (560 MB)
#
# [Session 623] Extracting video features...
#     Frames: 45242 total → 43118 valid (95.3% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/624_P.tar.gz... downloaded (303 MB)
#
# [Session 624] Extracting video features...
#     Frames: 25481 total → 23297 valid (91.4% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/625_P.tar.gz... downloaded (460 MB)
#
# [Session 625] Extracting video features...
#     Frames: 34693 total → 33472 valid (96.5% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/626_P.tar.gz... downloaded (262 MB)
#
# [Session 626] Extracting video features...
#     Frames: 18335 total → 17944 valid (97.9% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/629_P.tar.gz... downloaded (654 MB)
#
# [Session 629] Extracting video features...
#     Frames: 41914 total → 40882 valid (97.5% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/631_P.tar.gz... downloaded (238 MB)
#
# [Session 631] Extracting video features...
#     Frames: 18571 total → 18098 valid (97.5% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/634_P.tar.gz... downloaded (382 MB)
#
# [Session 634] Extracting video features...
#     Frames: 24524 total → 24066 valid (98.1% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/635_P.tar.gz... downloaded (236 MB)
#
# [Session 635] Extracting video features...
#     Frames: 15925 total → 15691 valid (98.5% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/636_P.tar.gz... downloaded (766 MB)
#
# [Session 636] Extracting video features...
#     Frames: 50605 total → 50273 valid (99.3% kept)
#     → 227 features extracted successfully
#
#   [Checkpoint] Saved 240 sessions to edaic_video_features.csv
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/637_P.tar.gz... downloaded (570 MB)
#
# [Session 637] Extracting video features...
#     Frames: 37358 total → 35716 valid (95.6% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/638_P.tar.gz... downloaded (217 MB)
#
# [Session 638] Extracting video features...
#     Frames: 15752 total → 14608 valid (92.7% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/640_P.tar.gz... downloaded (342 MB)
#
# [Session 640] Extracting video features...
#     Frames: 24406 total → 24066 valid (98.6% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/649_P.tar.gz... downloaded (470 MB)
#
# [Session 649] Extracting video features...
#     Frames: 29761 total → 29518 valid (99.2% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/650_P.tar.gz... downloaded (441 MB)
#
# [Session 650] Extracting video features...
#     Frames: 31071 total → 30641 valid (98.6% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/651_P.tar.gz... downloaded (228 MB)
#
# [Session 651] Extracting video features...
#     Frames: 17600 total → 17044 valid (96.8% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/652_P.tar.gz... downloaded (339 MB)
#
# [Session 652] Extracting video features...
#     Frames: 28599 total → 27426 valid (95.9% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/655_P.tar.gz... downloaded (339 MB)
#
# [Session 655] Extracting video features...
#     Frames: 25653 total → 25335 valid (98.8% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/656_P.tar.gz... downloaded (317 MB)
#
# [Session 656] Extracting video features...
#     Frames: 22912 total → 22463 valid (98.0% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/658_P.tar.gz... downloaded (430 MB)
#
# [Session 658] Extracting video features...
#     Frames: 29646 total → 29414 valid (99.2% kept)
#     → 227 features extracted successfully
#
#   [Checkpoint] Saved 250 sessions to edaic_video_features.csv
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/659_P.tar.gz... downloaded (485 MB)
#
# [Session 659] Extracting video features...
#     Frames: 38357 total → 37881 valid (98.8% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/661_P.tar.gz... downloaded (597 MB)
#
# [Session 661] Extracting video features...
#     Frames: 37609 total → 37363 valid (99.3% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/663_P.tar.gz... downloaded (392 MB)
#
# [Session 663] Extracting video features...
#     Frames: 26839 total → 26245 valid (97.8% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/664_P.tar.gz... downloaded (518 MB)
#
# [Session 664] Extracting video features...
#     Frames: 35950 total → 35024 valid (97.4% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/666_P.tar.gz... downloaded (550 MB)
#
# [Session 666] Extracting video features...
#     Frames: 36163 total → 35537 valid (98.3% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/669_P.tar.gz... downloaded (649 MB)
#
# [Session 669] Extracting video features...
#     Frames: 42273 total → 41977 valid (99.3% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/676_P.tar.gz... downloaded (210 MB)
#
# [Session 676] Extracting video features...
#     Frames: 17500 total → 17203 valid (98.3% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/679_P.tar.gz... downloaded (380 MB)
#
# [Session 679] Extracting video features...
#     Frames: 37161 total → 32311 valid (86.9% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/682_P.tar.gz... downloaded (318 MB)
#
# [Session 682] Extracting video features...
#     Frames: 22048 total → 21858 valid (99.1% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/683_P.tar.gz... downloaded (581 MB)
#
# [Session 683] Extracting video features...
#     Frames: 38516 total → 38442 valid (99.8% kept)
#     → 227 features extracted successfully
#
#   [Checkpoint] Saved 260 sessions to edaic_video_features.csv
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/688_P.tar.gz... downloaded (497 MB)
#
# [Session 688] Extracting video features...
#     Frames: 33811 total → 33644 valid (99.5% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/689_P.tar.gz... downloaded (375 MB)
#
# [Session 689] Extracting video features...
#     Frames: 26702 total → 26439 valid (99.0% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/691_P.tar.gz... downloaded (576 MB)
#
# [Session 691] Extracting video features...
#     Frames: 38940 total → 38454 valid (98.8% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/693_P.tar.gz... downloaded (292 MB)
#
# [Session 693] Extracting video features...
#     Frames: 20752 total → 20201 valid (97.3% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/696_P.tar.gz... downloaded (313 MB)
#
# [Session 696] Extracting video features...
#     Frames: 22907 total → 22581 valid (98.6% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/699_P.tar.gz... downloaded (305 MB)
#
# [Session 699] Extracting video features...
#     Frames: 21987 total → 20985 valid (95.4% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/705_P.tar.gz... downloaded (316 MB)
#
# [Session 705] Extracting video features...
#     Frames: 23580 total → 22047 valid (93.5% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/708_P.tar.gz... downloaded (364 MB)
#
# [Session 708] Extracting video features...
#     Frames: 26882 total → 26212 valid (97.5% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/709_P.tar.gz... downloaded (322 MB)
#
# [Session 709] Extracting video features...
#     Frames: 24592 total → 24529 valid (99.7% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/710_P.tar.gz... downloaded (353 MB)
#
# [Session 710] Extracting video features...
#     Frames: 24998 total → 24559 valid (98.2% kept)
#     → 227 features extracted successfully
#
#   [Checkpoint] Saved 270 sessions to edaic_video_features.csv
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/712_P.tar.gz... downloaded (543 MB)
#
# [Session 712] Extracting video features...
#     Frames: 36781 total → 36422 valid (99.0% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/715_P.tar.gz... downloaded (486 MB)
#
# [Session 715] Extracting video features...
#     Frames: 39099 total → 38672 valid (98.9% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/716_P.tar.gz... downloaded (430 MB)
#
# [Session 716] Extracting video features...
#     Frames: 29091 total → 28910 valid (99.4% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/717_P.tar.gz... downloaded (395 MB)
#
# [Session 717] Extracting video features...
#     Frames: 29387 total → 28819 valid (98.1% kept)
#     → 227 features extracted successfully
#   Streaming https://dcapswoz.ict.usc.edu/wwwedaic/data/718_P.tar.gz... downloaded (492 MB)
#
# [Session 718] Extracting video features...
#     Frames: 38456 total → 37991 valid (98.8% kept)
#     → 227 features extracted successfully
#
# ============================================================
# Done. 275 sessions extracted, 0 failed.
# Feature matrix shape: (275, 230)
# Saved to: edaic_video_features.csv
# Merged: 275 sessions with both features and labels
# Feature columns: 229
# NaN count before imputation: 0
# NaN count after imputation: 0
# Final feature matrix: (275, 229)
#
# Feature                                     Depressed  Not Depressed    Direction
# --------------------------------------------------------------------------------
# au_comp_duchenne_smile_rate                    0.1356         0.1637  ↓ depressed
# au_comp_neg_affect_mean                        0.4747         0.4895  ↓ depressed
# au_comp_agitation_mean                         0.3742         0.4039  ↓ depressed
# pose_velocity_mean                             0.0100         0.0108  ↓ depressed
# pose_stillness_rate                            0.6860         0.6549  ↑ depressed
# gaze_aversion_rate                             0.6711         0.6921  ↓ depressed
# gaze_instability_mean                          0.0476         0.0503  ↓ depressed

# %% [markdown]
# # 1. Notebook Title
#
# E-DAIC Video Feature Extraction and Analysis

# %% [markdown]
# # 2. One-line Summary
#
# This notebook provides a complete pipeline for extracting, cleaning, aggregating, and normalizing video-based behavioral features from the E-DAIC dataset using OpenFace outputs, with a focus on preparing data for depression detection models.

# %% [markdown]
# # 3. Project Goal
#
# -   **Objective**: The primary objective is to develop a robust and reproducible method for extracting comprehensive video-based behavioral features from the E-DAIC dataset's raw OpenFace outputs.
# -   **Research Question**: How can a rich set of video-based behavioral features, such as Action Units, head pose, and gaze dynamics, be extracted and processed from interview data to identify potential biomarkers for depression?
# -   **Engineering Problem**: To create an automated and scalable data pipeline that can download specific OpenFace output files from `tar.gz` archives, perform detailed feature engineering at the frame level, aggregate these features to a session level, and then preprocess them (imputation, normalization) for subsequent machine learning tasks.
# -   **Expected Output**: A CSV file containing session-level, preprocessed (imputed and Z-score normalized) video features for all participants, merged with their corresponding clinical labels (PHQ-8 scores, depression binary flags), suitable for direct input into classification or regression models.

# %% [markdown]
# # 4. Detailed Overview
#
# This notebook serves as a foundational component for video-based depression detection research, specifically targeting the E-DAIC (Emotion-DAIC) dataset. It meticulously details the process of converting raw, frame-level OpenFace outputs into meaningful, session-level feature vectors.
#
# The workflow begins with **data acquisition**, where `tar.gz` archives containing participant data are streamed directly from the E-DAIC server. Instead of downloading entire archives, the notebook intelligently extracts only the necessary OpenFace CSV files for each session, minimizing disk usage and speeding up the process. This streaming approach is crucial for handling large datasets efficiently.
#
# Following acquisition, the core **feature engineering** phase takes place. This involves several critical steps: loading OpenFace CSVs, performing initial data cleaning by filtering out low-confidence or failed tracking frames, and then extracting a diverse set of behavioral features. These features are categorized into Action Units (intensity, binary, and dynamic properties like activation rates and bout durations), Head Pose (statistical summaries, velocity, stillness, and tilt behaviors), and Gaze (statistical summaries, instability, aversion, and velocity). Importantly, clinically relevant composites, such as the Duchenne smile rate and negative affect scores, are also computed to provide higher-level insights.
#
# **Data preprocessing** ensures that the extracted features are suitable for machine learning. This includes aggregating the frame-level features to a single vector per session, merging these features with the participant's demographic and clinical labels (including PHQ-8 scores and depression binary flags), handling missing values through imputation (median by default), and finally, applying Z-score normalization. A critical design decision here is to compute imputation values and normalization parameters solely from the training data split to prevent data leakage and ensure realistic model evaluation.
#
# Finally, the notebook includes a **clinical interpretation** step, which summarizes key features by comparing their average values between depressed and non-depressed groups. This serves as a sanity check and provides initial insights into which behavioral markers might differentiate between the two cohorts, aligning with existing psychological literature (e.g., lower smile rates, higher gaze aversion in depressed individuals). The overall methodology is designed to be robust and comprehensive, translating low-level video cues into high-level behavioral indicators pertinent to mental health assessment.

# %% [markdown]
# # 5. Workflow Breakdown
#
# The notebook follows a structured workflow to process video data from the E-DAIC dataset:
#
# 1.  **Data Loading & Acquisition (External)**
#     *   **Files loaded**: `tar.gz` archives from the E-DAIC server containing OpenFace CSVs (e.g., `XXX_OpenFace2.1.0_Pose_gaze_AUs.csv`), and various label CSVs (`train_split.csv`, `dev_split.csv`, `test_split.csv`, `Detailed_PHQ8_Labels.csv`, `metadata_mapped.csv`).
#     *   **Formats**: `tar.gz` for raw video features, CSV for labels and OpenFace outputs.
#     *   **Assumptions**: The `tar.gz` archives are structured with a specific path for the OpenFace CSVs (`{sid}_P/features/{sid}_OpenFace2.1.0_Pose_gaze_AUs.csv`). Label files are accessible at a specified URL.
#     *   **Details**: The notebook streams tar.gz files from a remote URL to avoid full downloads. It identifies and extracts only the required OpenFace feature CSV for each participant (`stream_openface_from_tar` function). Label files are downloaded directly from the server or from a bundled `labels2019.tar.gz` file and concatenated into a single DataFrame.
#
# 2.  **Initial Cleaning (Per Session)**
#     *   **Missing values**: Handled by filtering out frames with low confidence or failed tracking.
#     *   **Duplicates**: Not explicitly handled at the frame level, but filtering by `success` and `confidence` implicitly removes unreliable data points.
#     *   **Filtering**: Frames are filtered based on `confidence >= CONFIDENCE_THRESHOLD` (default 0.8) and `success == 1` to ensure high-quality tracking data. Sessions with fewer than 100 valid frames after filtering are skipped to avoid unreliable feature extraction.
#     *   **Details**: The `load_openface_csv` function performs this cleaning. Column names are also stripped of whitespace, an identified quirk of OpenFace outputs.
#
# 3.  **Feature Engineering (Per Session)**
#     *   **Generated features**: A rich set of session-level features are generated from frame-level OpenFace outputs.
#         *   **Action Units (AU)**: Statistical aggregations (mean, std, min, max, range, median, p25, p75) of 17 AU intensities. Binary presence rates for 17 AUs. Clinical composites: Duchenne smile rate and intensity (AU06 + AU12), Negative affect score (AU04 + AU15 + AU17), Agitation composite (AU01 + AU02 + AU25). Dynamic features: AU activation rates (0→1 transitions per minute) and mean bout durations (average consecutive active frames) for key AUs.
#         *   **Head Pose**: Statistical aggregations (mean, std, min, max, range, median, p25, p75) of `pose_Rx`, `pose_Ry`, `pose_Rz` (pitch, yaw, roll). Head movement velocity (Euclidean distance of angular change), stillness rate (low velocity frames), total path length, and downward tilt rate.
#         *   **Gaze**: Statistical aggregations (mean, std, min, max, range, median, p25, p75) of `gaze_angle_x` and `gaze_angle_y`. Gaze instability (rolling window standard deviation), aversion rate (gaze far from center), downward gaze rate, and gaze velocity.
#     *   **Transformations**: Frame-level data is transformed into statistical summaries and dynamic metrics. Composites are calculated from multiple AUs. Frame timestamps are used to estimate frames per second (FPS) for dynamic feature calculations.
#     *   **Scaling**: Not done in this step, but later in post-processing.
#     *   **Details**: Functions like `extract_au_features`, `extract_pose_features`, `extract_gaze_features`, and `aggregate_stats` are responsible for this. The `extract_video_features` function orchestrates the extraction for a single session.
#
# 4.  **Aggregation to Dataset Level**
#     *   **Features collected**: All session-level features for all participants in the `label_df` are collected into a single DataFrame (`feature_df`).
#     *   **Details**: The `extract_all_sessions` function iterates through `Participant_ID`s, streams each OpenFace CSV, extracts features, and appends them to a list which is then converted to a DataFrame. It also handles checkpointing to save intermediate results.
#
# 5.  **Post-processing & Normalization**
#     *   **Missing values**: Imputed using `median` (default) or `mean` from the *training split only* to prevent data leakage. Alternatively, can be zero-filled.
#     *   **Merging**: The extracted `feature_df` is merged with the `all_labels` DataFrame using `Participant_ID`.
#     *   **Normalization**: All feature columns are Z-score normalized (mean subtraction, division by standard deviation). The mean and standard deviation for normalization are calculated *only from the training split* and then applied to all splits (train, dev, test) to prevent data leakage.
#     *   **Details**: The `postprocess_features` function executes these steps.
#
# 6.  **Clinical Interpretation & Summary**
#     *   **Features summarized**: Key behavioral features (duchenne smile rate, negative affect, agitation, pose velocity, stillness, gaze aversion, gaze instability).
#     *   **Insights**: The `summarise_features` function calculates and prints the mean values for selected features for both depressed and non-depressed participant groups. It indicates the direction of difference (e.g., '↓ depressed' means lower in the depressed group) to provide a quick clinical sanity check and interpretation.

# %% [markdown]
# # 6. Libraries Used
#
# | Library       | Purpose                                                                                                                              |
# | :------------ | :----------------------------------------------------------------------------------------------------------------------------------- |
# | `tarfile`     | For working with `tar.gz` archives, specifically to open and extract files from streamed buffers without saving the entire archive.   |
# | `urllib.request` | Used in the initial example (NXkRAhL4FmNK) for opening URLs and reading HTTP responses. Later replaced by `requests`.                     |
# | `io`          | For in-memory binary streams (`io.BytesIO`) and text streams (`io.StringIO`), crucial for handling data without writing to disk.      |
# | `requests`    | For making HTTP requests to download data and label files from the E-DAIC server, and for streaming `tar.gz` archives.                 |
# | `bs4` (`BeautifulSoup`)| For parsing HTML content (e.g., from directory listings) to discover available files, as shown in `ppGINsteCbX_`.                   |
# | `pandas`      | Core library for data manipulation and analysis, used extensively for DataFrame operations, CSV reading/writing, and data aggregation. |
# | `numpy`       | For numerical operations, especially array manipulations, statistical calculations, and handling NaN values.                         |
# | `os`          | For interacting with the operating system, such as creating directories (`os.makedirs`) and managing file paths (`os.path.join`).    |
# | `pathlib`     | (Imported but not explicitly used in the main functions) Provides an object-oriented filesystem path manipulation.                   |
# | `sys`         | For interacting with the Python interpreter, used to check command-line arguments (`sys.argv`) for running single session tests.     |
#
# **Purpose of each library:**
#
# *   **`tarfile`**: Essential for directly interacting with `.tar.gz` files from URLs. It allows selective extraction of files from these archives without requiring the entire archive to be downloaded and saved to disk first. This is critical for efficiency given the size of the E-DAIC data archives.
# *   **`urllib.request`**: Provides a way to fetch URLs. It was used in an early example for illustration but `requests` is generally preferred for its more user-friendly API and robust error handling.
# *   **`io`**: Enables the handling of data in memory as if it were a file. `io.BytesIO` is key for managing binary data streamed from `tar.gz` files, and `io.StringIO` is used for parsing CSV strings into pandas DataFrames, avoiding temporary file creation.
# *   **`requests`**: A powerful and flexible HTTP library used for reliably downloading data from the web, including large files (with `stream=True`) and listing directory contents. It's preferred over `urllib.request` for most modern web interactions.
# *   **`bs4` (`BeautifulSoup`)**: Used for web scraping, specifically to parse HTML responses from directory listings to identify and list available label files on the E-DAIC server. This helps in understanding the data available for download.
# *   **`pandas`**: The backbone of the data processing. It handles loading CSVs, cleaning DataFrames, performing complex aggregations, merging different data sources (features and labels), and managing missing data. Its DataFrame structure is central to organizing and manipulating the extracted features.
# *   **`numpy`**: Provides fundamental numerical computing capabilities. It's used for efficient array operations, calculating statistics (mean, std, percentile), handling mathematical functions (e.diff, np.sqrt, np.sum), and managing numerical data, especially when dealing with large feature vectors.
# *   **`os`**: Used for standard operating system interactions, primarily for creating directories to save downloaded label files or extracted feature files. It helps in organizing the output of the notebook.
# *   **`pathlib`**: (While imported, its direct usage isn't prominent in the provided code snippets for functions.) It offers an object-oriented way to represent file system paths, which can lead to cleaner and more readable code for path manipulation compared to `os.path`.
# *   **`sys`**: Used to inspect command-line arguments. In this notebook, it's used to determine if the script should run a quick test on a single session or process the full dataset, providing flexibility in execution.
